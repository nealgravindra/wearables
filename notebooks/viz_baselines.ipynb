# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os
import time
import pickle
import datetime
import ast

import torch

import sys
sfp = '/home/ngr4/project/'
sys.path.append(sfp)
from wearables.scripts import models_v3 as wearmodels
from wearables.scripts import data_v3 as weardata
from wearables.scripts import eval_v3 as weareval
from wearables.scripts import utils as wearutils
from wearables.scripts import baselines as wearbase

plt.rc('font', size = 9)
plt.rc('font', family='sans serif')
plt.rcParams['pdf.fonttype']=42
plt.rcParams['ps.fonttype']=42
plt.rcParams['legend.frameon']=False
plt.rcParams['axes.grid']=False
plt.rcParams['legend.markerscale']=0.5
plt.rcParams['savefig.dpi']=600
sns.set_style("ticks")

# %%
knn = wearbase.KNN()
# Out:
# Test set eval:
#   <MAE>: 9.1 (0.00)
# Test set eval:
#   <MAE>: 9.0 (0.07)
# Test set eval:
#   <MAE>: 8.9 (0.23)
# Test set eval:
#   <MAE>: 9.0 (0.29)
# Test set eval:
#   <MAE>: 9.0 (0.26)
# Test set eval:
#   <MAE>: 9.0 (0.26)

# %%
rf =  wearbase.RF()

# %%
lightgbm = wearbase.lightgbm()
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.289180 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2115826
# [LightGBM] [Info] Number of data points in the train set: 2095, number of used features: 10081
# [LightGBM] [Info] Start training from score 19.921718
# [1]	valid_0's l2: 98.4174
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's l2: 98.8888
# [3]	valid_0's l2: 98.6512
# [4]	valid_0's l2: 98.1528
# [5]	valid_0's l2: 96.8147
# [6]	valid_0's l2: 97.3636
# [7]	valid_0's l2: 97.2883
# [8]	valid_0's l2: 97.4078
# [9]	valid_0's l2: 96.988
# [10]	valid_0's l2: 96.2791
# [11]	valid_0's l2: 96.6997
# [12]	valid_0's l2: 97.0477
# [13]	valid_0's l2: 97.0626
# [14]	valid_0's l2: 97.0265
# [15]	valid_0's l2: 97.0835
# [16]	valid_0's l2: 97.6881
# [17]	valid_0's l2: 96.6882
# [18]	valid_0's l2: 96.9418
# [19]	valid_0's l2: 97.5548
# [20]	valid_0's l2: 97.4502
# Early stopping, best iteration is:
# [10]	valid_0's l2: 96.2791
#   through 1 trials in 84-s, total elapsed: 1.4-min
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.295097 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2108097
# [LightGBM] [Info] Number of data points in the train set: 2079, number of used features: 10081
# [LightGBM] [Info] Start training from score 19.804233
# [1]	valid_0's l2: 94.4067
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's l2: 93.2221
# [3]	valid_0's l2: 92.849
# [4]	valid_0's l2: 93.0007
# [5]	valid_0's l2: 92.9747
# [6]	valid_0's l2: 93.0209
# [7]	valid_0's l2: 93.3125
# [8]	valid_0's l2: 93.3828
# [9]	valid_0's l2: 94.2515
# [10]	valid_0's l2: 94.1787
# [11]	valid_0's l2: 94.2992
# [12]	valid_0's l2: 95.222
# [13]	valid_0's l2: 95.6863
# Early stopping, best iteration is:
# [3]	valid_0's l2: 92.849
#   through 2 trials in 77-s, total elapsed: 2.7-min
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.300945 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2119111
# [LightGBM] [Info] Number of data points in the train set: 2110, number of used features: 10081
# [LightGBM] [Info] Start training from score 19.945972
# [1]	valid_0's l2: 94.6724
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's l2: 94.1801
# [3]	valid_0's l2: 93.6336
# [4]	valid_0's l2: 93.1928
# [5]	valid_0's l2: 92.6367
# [6]	valid_0's l2: 92.476
# [7]	valid_0's l2: 92.8483
# [8]	valid_0's l2: 93.5458
# [9]	valid_0's l2: 93.8136
# [10]	valid_0's l2: 94.6466
# [11]	valid_0's l2: 95.4861
# [12]	valid_0's l2: 95.298
# [13]	valid_0's l2: 95.3644
# [14]	valid_0's l2: 95.4201
# [15]	valid_0's l2: 95.3229
# [16]	valid_0's l2: 95.9901
# Early stopping, best iteration is:
# [6]	valid_0's l2: 92.476
#   through 3 trials in 82-s, total elapsed: 4.0-min
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.304085 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2108312
# [LightGBM] [Info] Number of data points in the train set: 2068, number of used features: 10081
# [LightGBM] [Info] Start training from score 19.850580
# [1]	valid_0's l2: 93.6187
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's l2: 93.238
# [3]	valid_0's l2: 92.4671
# [4]	valid_0's l2: 92.2667
# [5]	valid_0's l2: 91.6753
# [6]	valid_0's l2: 92.2044
# [7]	valid_0's l2: 92.4018
# [8]	valid_0's l2: 92.1207
# [9]	valid_0's l2: 92.1166
# [10]	valid_0's l2: 91.8697
# [11]	valid_0's l2: 92.2138
# [12]	valid_0's l2: 92.2332
# [13]	valid_0's l2: 92.5593
# [14]	valid_0's l2: 92.4804
# [15]	valid_0's l2: 92.3634
# Early stopping, best iteration is:
# [5]	valid_0's l2: 91.6753
#   through 4 trials in 81-s, total elapsed: 5.4-min
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.333594 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2107934
# [LightGBM] [Info] Number of data points in the train set: 2086, number of used features: 10081
# [LightGBM] [Info] Start training from score 19.919463
# [1]	valid_0's l2: 97.5542
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's l2: 96.934
# [3]	valid_0's l2: 96.9045
# [4]	valid_0's l2: 96.6593
# [5]	valid_0's l2: 96.9048
# [6]	valid_0's l2: 97.2118
# [7]	valid_0's l2: 97.2128
# [8]	valid_0's l2: 97.2682
# [9]	valid_0's l2: 97.275
# [10]	valid_0's l2: 97.5372
# [11]	valid_0's l2: 97.3086
# [12]	valid_0's l2: 97.1882
# [13]	valid_0's l2: 97.4037
# [14]	valid_0's l2: 97.7259
# Early stopping, best iteration is:
# [4]	valid_0's l2: 96.6593
#   through 5 trials in 79-s, total elapsed: 6.7-min
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.299123 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2104343
# [LightGBM] [Info] Number of data points in the train set: 2086, number of used features: 10081
# [LightGBM] [Info] Start training from score 19.931448
# [1]	valid_0's l2: 96.1556
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's l2: 96.3922
# [3]	valid_0's l2: 96.7417
# [4]	valid_0's l2: 96.512
# [5]	valid_0's l2: 97.8922
# [6]	valid_0's l2: 97.4326
# [7]	valid_0's l2: 97.5526
# [8]	valid_0's l2: 96.9889
# [9]	valid_0's l2: 95.7542
# [10]	valid_0's l2: 95.4369
# [11]	valid_0's l2: 95.4278
# [12]	valid_0's l2: 95.9136
# [13]	valid_0's l2: 96.2984
# [14]	valid_0's l2: 95.8791
# [15]	valid_0's l2: 95.6391
# [16]	valid_0's l2: 95.8103
# [17]	valid_0's l2: 96.1123
# [18]	valid_0's l2: 95.6544
# [19]	valid_0's l2: 96.0795
# [20]	valid_0's l2: 95.8506
# [21]	valid_0's l2: 95.3032
# [22]	valid_0's l2: 95.7332
# [23]	valid_0's l2: 95.4797
# [24]	valid_0's l2: 95.5573
# [25]	valid_0's l2: 95.3415
# [26]	valid_0's l2: 95.57
# [27]	valid_0's l2: 95.6045
# [28]	valid_0's l2: 95.626
# [29]	valid_0's l2: 95.3261
# [30]	valid_0's l2: 95.2143
# [31]	valid_0's l2: 95.1195
# [32]	valid_0's l2: 94.9522
# [33]	valid_0's l2: 95.1648
# [34]	valid_0's l2: 95.4362
# [35]	valid_0's l2: 95.5961
# [36]	valid_0's l2: 96.0669
# [37]	valid_0's l2: 96.2665
# [38]	valid_0's l2: 96.4506
# [39]	valid_0's l2: 96.4255
# [40]	valid_0's l2: 96.5726
# [41]	valid_0's l2: 96.7223
# [42]	valid_0's l2: 96.9607
# Early stopping, best iteration is:
# [32]	valid_0's l2: 94.9522
#   through 6 trials in 92-s, total elapsed: 8.2-min
# Test set eval:
#   <MAE>: 8.6 (0.21)

# %%
import importlib
importlib.reload(wearbase)
# Out:
# <module 'wearables.scripts.baselines' from '/home/ngr4/project/wearables/scripts/baselines.py'>

# %%
model_data = wearbase.get_data()
X_train, y_train = model_data['train']
