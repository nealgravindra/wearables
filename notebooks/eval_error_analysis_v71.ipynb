# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import glob
import os
import time
import pickle
import datetime
import networkx as nx

import sys
sys.path.append('/home/ngrav/project/')
from wearables.scripts import utils as wearutils
from wearables.scripts import data as weardata
from wearables.scripts import train as weartrain
from wearables.scripts import eval_ as weareval
from wearables.scripts import model as wearmodels
from wearables.scripts import DTW as weardtw
from wearables.scripts import error_analysis as wearerr

import torch
import torch.nn as nn
import torch.nn.functional as F

from scipy.stats import spearmanr
from scipy.stats import chi2_contingency
from scipy.stats import kruskal
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sktime.datatypes._panel._convert import from_2d_array_to_nested
from sktime.regression.compose._ensemble import ComposableTimeSeriesForestRegressor
from sktime.classification.compose import ComposableTimeSeriesForestClassifier

import matplotlib.pyplot as plt
import seaborn as sns
from adjustText import adjust_text
plt.rc('font', size = 9)
plt.rc('font', family='sans serif')
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
plt.rcParams['legend.frameon']=False
plt.rcParams['axes.grid']=False
plt.rcParams['legend.markerscale']=1
plt.rcParams['savefig.dpi'] = 600
sns.set_style("ticks")

def loadpkl(fp):
    with open(fp, 'rb') as f:
        return pickle.load(f)

# %%
# load data

pfp = '/home/ngrav/project/wearables/results/'
mfp = '/home/ngrav/scratch/wearables_model_zoo'

# filepaths to bst or pre-processed md with calculated metrics 
pp_md_fp = os.path.join(pfp, 'md_v522_220124.csv')
bst_trainer = os.path.join(mfp, 'trainer_itv71_InceptionTime_GA4.pkl')
bst_modelpkl = os.path.join(mfp, '281-itv71_InceptionTime_GA4.pkl')

# load up to date md
md = pd.read_csv(pp_md_fp, index_col=0)
trainer = loadpkl(bst_trainer)

if False:
    # call eval to get output, modify for return_hidden = True option
    evaluation = weareval.eval_trained(trainer, split='train',
                                       modelpkl=bst_modelpkl,
                                       two_outputs=True)

# %%
# filter out md so there is no chance of error
print('md shape:', md.shape)
cohort = pd.read_csv('/home/ngrav/data/wearables/processed/List_1260.csv')
valid_ids = cohort['x'].to_list() # convert to int64?
md = md.loc[md['record_id'].isin(valid_ids), :]
print('valid md shape:', md.shape)
# Out:
# md shape: (2305, 130)
# valid md shape: (2305, 130)

# %% [markdown]
# # show error in train and test set

# %%
# define parameters
idxs = trainer.data.train_ids
threshold = 10 # for error groups

savefigs = False

# %%
# parse data and plot
y = md.loc[idxs, 'y']
yhat = md.loc[idxs, 'yhat']
error = md.loc[idxs, 'error']

fig, ax = plt.subplots(1, 1, figsize=(4.5, 3))
im = ax.scatter(y, yhat, c=error.abs(), cmap='RdYlBu_r', linewidth=0, s=16, alpha=0.8)
fig.colorbar(im, ax=ax, label='Absolute error (wks)')
x0, x1 = ax.get_xlim()
y0, y1 = ax.get_ylim()
ax.plot([x0, x1], [x0+threshold, x1+threshold], 'k--', alpha=0.5)
ax.plot([x0, x1], [x0-threshold, x1-threshold], 'k--', alpha=0.5)
ax.set_xlim([x0, x1])
ax.set_ylim([y0, y1])
rho, p = spearmanr(y, yhat)
p_txt = 'P={:.2f}'.format(p) if p > 0.001 else 'P<0.001'
ax.text(0.1, 0.9, 'r={:.2f} ({})'.format(rho, p_txt), transform=ax.transAxes) 
ax.set_xlabel('Y (GA in wks)')
ax.set_ylabel('Yhat (GA in wks)')
ax.set_title('Train set error')

if savefigs:
    fig.savefig(os.path.join(pfp, 'scatter_yhatVy_train.pdf'), bbox_inches='tight')

# %% [markdown]
# ### assign error grp

# %%
md['Error group'] = 'lt{}wks'.format(threshold)
md.loc[(md['error'] >= threshold), 'Error group'] = 'Higher-than-actual'
md.loc[(md['error'] <= -threshold), 'Error group'] = 'Lower-than-actual'

# %%
md.loc[idxs, 'Error group'].value_counts()
# Out:
# lt10wks               1054
# Lower-than-actual      223
# Higher-than-actual     134
# Name: Error group, dtype: int64

# %%
errgrp_cmap = {'lt{}wks'.format(threshold): '#4297A0', # green
               'Higher-than-actual': '#E57F84', #red
               'Lower-than-actual': '#2F5061', # blue
               }

# %%
fig, ax = plt.subplots(1, 1, figsize=(4, 3))
sns.scatterplot(x='y', y='yhat', hue='Error group', data=md.loc[idxs], palette=errgrp_cmap, linewidth=0, alpha=0.8, ax=ax)
ax.set_xlabel('Y (GA in wks)')
ax.set_ylabel('Yhat (GA in wks)')
ax.set_title('Error groups (train set)')
ax.legend().set_title('')

if savefigs:
    fig.savefig(os.path.join(pfp, 'scatter_yhatVy_train_errorgroups.pdf'), bbox_inches='tight')

# %% [markdown]
# ## chk the same in the test set m

# %%
# define parameters
idxs = trainer.data.test_ids

# %%
# parse data and plot
y = md.loc[idxs, 'y']
yhat = md.loc[idxs, 'yhat']
error = md.loc[idxs, 'error']

fig, ax = plt.subplots(1, 1, figsize=(4.5, 3))
im = ax.scatter(y, yhat, c=error.abs(), cmap='RdYlBu_r', linewidth=0, s=16, alpha=0.8)
fig.colorbar(im, ax=ax, label='Absolute error (wks)')
x0, x1 = ax.get_xlim()
y0, y1 = ax.get_ylim()
ax.plot([x0, x1], [x0+threshold, x1+threshold], 'k--', alpha=0.5)
ax.plot([x0, x1], [x0-threshold, x1-threshold], 'k--', alpha=0.5)
ax.set_xlim([x0, x1])
ax.set_ylim([y0, y1])
rho, p = spearmanr(y, yhat)
p_txt = 'P={:.2f}'.format(p) if p > 0.001 else 'P<0.001'
ax.text(0.1, 0.9, 'r={:.2f} ({})'.format(rho, p_txt), transform=ax.transAxes) 
ax.set_xlabel('Y (GA in wks)')
ax.set_ylabel('Yhat (GA in wks)')
ax.set_title('Test set error')

if savefigs:
    fig.savefig(os.path.join(pfp, 'scatter_yhatVy_test.pdf'), bbox_inches='tight')

# %%
fig, ax = plt.subplots(1, 1, figsize=(4, 3))
sns.scatterplot(x='y', y='yhat', hue='Error group', data=md.loc[idxs], palette=errgrp_cmap, linewidth=0, alpha=0.8, ax=ax)
ax.set_xlabel('Y (GA in wks)')
ax.set_ylabel('Yhat (GA in wks)')
ax.set_title('Error groups (test set)')
ax.legend().set_title('')

if savefigs:
    fig.savefig(os.path.join(pfp, 'scatter_yhatVy_test_errorgroups.pdf'), bbox_inches='tight')

# %%
md.loc[idxs, 'Error group'].value_counts()
# Out:
# lt10wks               488
# Lower-than-actual     143
# Higher-than-actual     60
# Name: Error group, dtype: int64

# %% [markdown]
# # md differences across err grp

# %%
# grab list of vars to predict (mdpred_voi)
from wearables.scripts.md_specification import mdpred_voi

# %%
import importlib
importlib.reload(wearutils)
# Out:
# <module 'wearables.scripts.utils' from '/home/ngrav/project/wearables/scripts/utils.py'>

# %%
resknn10 = loadpkl(os.path.join(pfp, 'md_predictability_knn_10wk.pkl'))
# resknn8 = loadpkl(os.path.join(pfp, 'md_predictability_knn_8wk.pkl'))

# %%
moi = wearutils.metric_list(resknn10, mdpred_voi, top1=True) #, clf_metric='balanced_acc')
# moi = wearutils.metric_list(resknn8, mdpred_voi)

# %%
savefigs = False

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 4))
# p_threshold = -np.log10(0.05/len(mdpred_voi.keys())) # bonferroni
p_threshold = -np.log10(0.05)
clip_color=True
texts = []
x, y, c = [], [], []
for k in moi.keys():
    x.append(moi[k][1])
    y.append(moi[k][0])
    c.append(moi[k][2])
    if moi[k][0] > p_threshold:
        texts.append(ax.text(moi[k][1], moi[k][0], k, size=8))
im = ax.scatter(x, y, c=c, cmap='RdYlBu_r', s=20, vmin=0, vmax=1)
fig.colorbar(im, ax=ax, label='(% improvement AU-PRC) or (1-MAPE)')
ax.plot([0, 1], [p_threshold, p_threshold], 'k--')
adjust_text(texts, arrowprops=dict(arrowstyle='-', color='k'), force_text=(0.12, 0.3))
ax.set_xlabel('Predictability (AU-PRC or |Rho|)')
ax.set_ylabel('-log10(P) between error groups')

if savefigs:
    fig.savefig(os.path.join(pfp, 'scatter_errgroupdiffVpredictability_knn.pdf'), bbox_inches='tight')

# %% [markdown]
# # corrnet

# %%
from scipy.stats import spearmanr
from sklearn.linear_model import LogisticRegression
import sklearn.metrics as sklmetrics
from sklearn.exceptions import ConvergenceWarning

# %%
def tabular_corrnet(md, mdpred_voi, edge_w_threshold=0.5):
    '''Calculate correlations (will need to take absolute value) for cont-cont using Spearman's rho,
         cont-cat using logistic regression on the categorical (max of balanced acc, adj., i.e., Youden's J),
         and Goodman Kruskal gamma for cat-cat variable comparisons.
    
    Arguments:
      md (pd.DataFrame): of mixed categorical and continuous variables. Must have a split column specifying train and
        test splits so logistic regression can be run
      mdpred_voi (dict): specify name of column in md as a key and the type of var as a value, accepts 'continuous' or 'categorical' 
        values in order to trigger the appropriate analysis.
        
    Returns:
      pd.DataFrame, nx.Graph
    '''
    from scipy.stats import spearmanr
    from sklearn.linear_model import LogisticRegression
    import sklearn.metrics as sklmetrics
    from sklearn.exceptions import ConvergenceWarning
    variables = list(mdpred_voi.keys())
    df = pd.DataFrame(index=variables, columns=variables)
    for i in range(len(variables)):
        for j in range(len(variables)):
            if i<=j:
                continue
            else:
                k, kk = variables[i], variables[j]
                v, vv = mdpred_voi[k], mdpred_voi[kk]
                if v == 'continuous' and vv == 'continuous':
                    # spearman's rho 
                    rho, p = spearmanr(md[k], md[kk])
                    df.loc[k, kk] = rho
                    df.loc[kk, k] = rho
                elif (v == 'continuous' and vv == 'categorical') or (v == 'categorical' and vv == 'continuous'):
                    # logistic regression
                    contvar = k if v == 'continuous' else kk
                    catvar = k if v == 'categorical' else kk
                    X_train = md.loc[md['split']=='train', contvar].to_numpy(dtype=np.float64).reshape(-1, 1)
                    X_test = md.loc[md['split']=='test', contvar].to_numpy(dtype=np.float64).reshape(-1, 1)
                    y_train = md.loc[md['split']=='train', catvar]
                    y_test = md.loc[md['split']=='test', catvar]
                    if len(y_train.unique()) < 1:
                        print(f"only one val found for {catvar}")
                    elif len(y_train.unique()) > 2:
                        y_train = y_train.to_numpy(dtype=int)
                        y_test = y_test.to_numpy(dtype=int)
                        y_train_wide = np.zeros((y_train.shape[0], len(np.unique(y_train))), dtype=int)
                        y_test_wide = np.zeros((y_test.shape[0], len(np.unique(y_train))), dtype=int)
                        y_train_wide[np.arange(y_train.shape[0]), y_train] = 1
                        y_test_wide[np.arange(y_test.shape[0]), y_test] = 1

                        y_train = y_train_wide
                        del y_train_wide
                        y_test = y_test_wide 
                        del y_test_wide
                    else:
                        y_train = y_train.to_numpy(dtype=int).reshape(-1, 1)
                        y_test = y_test.to_numpy(dtype=int).reshape(-1, 1)
                    balanced_acc = [] # Youden's J
                    for j in range(y_train.shape[1]):
                        lr = LogisticRegression(penalty='elasticnet', solver='saga', l1_ratio=0.1)
                        lr.fit(X_train, y_train[:, j])
                        balanced_acc.append(
                            sklmetrics.balanced_accuracy_score(y_test[:, j], lr.predict(X_test), adjusted=True)
                        )
                    df.loc[k, kk] = np.max(balanced_acc) # max agg?
                    df.loc[kk, k] = np.max(balanced_acc) # max agg?
                else:
                    # cat v. cat
                    GKgamma = wearerr.goodmanKruskalgamma(md, k, kk)
                    df.loc[k, kk] = GKgamma 
                    df.loc[kk, k] = GKgamma
    return df

# %%
df = tabular_corrnet(md, mdpred_voi)
# Out:
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1994: RuntimeWarning: invalid value encountered in double_scalars
#   score /= 1 - chance
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
p = sns.clustermap(df.fillna(0).abs(), yticklabels=1, xticklabels=2, cmap='RdYlBu_r')
# p.savefig(os.path.join(pfp, 'md_corrnet_v2.pdf'), bbox_inches='tight')
# Out:
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/seaborn/matrix.py:649: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/seaborn/matrix.py:619: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage = hierarchy.linkage(self.array, method=self.method,

# %% [markdown]
# ## pval only
#
# Size and color by pval across error groups

# %%
corr_threshold = 0.6
G = nx.Graph()
for k, v in moi.items():
    G.add_node(k, size=v[0], color=v[0])
variables = df.columns.to_list()
for i in range(len(variables)):
    for j in range(len(variables)):
        if i <= j: 
            continue
        else: 
            k, kk = variables[i], variables[j]
            w = np.abs(df.loc[k, kk])
            if w > corr_threshold:
                G.add_edge(k, kk, weight=w)
G.remove_nodes_from(list(nx.isolates(G)))
pos = nx.spring_layout(G, k=0.5)

# %%
p_threshold = -np.log10(0.05)

# %%
def range_scale(x, min_target=100, max_target=300):
    return ((x - np.min(x)) / (np.max(x) - np.min(x)))*(max_target - min_target) + min_target

# %%
# plot
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
node_sizes = [G.nodes[n]['size'] for n in G.nodes()]
im = nx.draw_networkx_nodes(
    G, pos=pos, label=False,
    nodelist=G.nodes(),
    node_color=[G.nodes[n]['color'] for n in G.nodes()],
    node_size=range_scale([G.nodes[n]['size'] for n in G.nodes()], min_target=50, max_target=200),
    cmap='coolwarm',
    ax=ax)
for edge in G.edges:
    ax.annotate('',
                xy=pos[edge[0]], 
                xytext=pos[edge[1]], 
                xycoords='data',
                textcoords='data',
                arrowprops=dict(arrowstyle="-", color='k',
                                linewidth=((np.exp(G.edges[edge]['weight']) - np.exp(0))/(np.exp(1) - np.exp(0)))*2.5+0.5, 
                                alpha=0.2,
                                shrinkA=0.5, shrinkB=0.5,
                                patchA=None, patchB=None,
                                connectionstyle="arc3,rad=-0.1",),
                zorder=0,
                )
if False:
    # show tecxt that is sig only?
    texts = []
    for k in moi.keys():
        if moi[k][0] > p_threshold and k in list(G.nodes):
            texts.append(ax.text(pos[k][0], pos[k][1], k, size=9))
    # adjust_text(texts, arrowprops=dict(arrowstyle='-', color='k'), force_text=(0.12, 0.3))
    adjust_text(texts, force_text=(0.12, 0.3))
fig.colorbar(im, ax=ax, label='-log10(P) between error groups')
fig.savefig(os.path.join(pfp, 'corrnet_sizePval_btwerrgrp_sigtxt.pdf'))

# %%
# plot
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
im = nx.draw_networkx_nodes(
    G, pos=pos, label=False,
    nodelist=G.nodes(),
    node_color=[G.nodes[n]['color'] for n in G.nodes()],
    node_size=range_scale([G.nodes[n]['size'] for n in G.nodes()], min_target=50, max_target=200),
    cmap='coolwarm',
    ax=ax)
for edge in G.edges:
    ax.annotate('',
                xy=pos[edge[0]], 
                xytext=pos[edge[1]], 
                xycoords='data',
                textcoords='data',
                arrowprops=dict(arrowstyle="-", color='k',
                                linewidth=((np.exp(G.edges[edge]['weight']) - np.exp(0))/(np.exp(1) - np.exp(0)))*2.5+0.5, 
                                alpha=0.2,
                                shrinkA=0.5, shrinkB=0.5,
                                patchA=None, patchB=None,
                                connectionstyle="arc3,rad=-0.1",),
                zorder=0,
                )
if True:
    texts = []
    # all 
    for k in G.nodes():
        if moi[k][0] > p_threshold:
            weight='bold'
        else:
            weight='normal'
        texts.append(ax.text(pos[k][0], pos[k][1], k, size=9, weight=weight))
    adjust_text(texts, arrowprops=dict(arrowstyle='-', color='k'), force_text=(0.12, 0.3))
fig.colorbar(im, ax=ax, label='-log10(P) between error groups')
fig.savefig(os.path.join(pfp, 'corrnet_sizePval_btwerrgrp_alltxt.pdf'))

# %% [markdown]
# ## pval and predictability

# %%
# update graph
for k in G.nodes:
    G.nodes[k]['size'] = moi[k][2] if not np.isnan(moi[k][2]) or np.isinf(moi[k][2]) else 0
    G.nodes[k]['color'] = moi[k][0]

# %%
# plot
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
node_sizes = [G.nodes[n]['size'] for n in G.nodes()]
im = nx.draw_networkx_nodes(
    G, pos=pos, label=False,
    nodelist=G.nodes(),
    node_color=[G.nodes[n]['color'] for n in G.nodes()],
    node_size=range_scale(np.exp([G.nodes[n]['size'] for n in G.nodes()]), min_target=50, max_target=200),
    cmap='coolwarm',
    ax=ax)
for edge in G.edges:
    ax.annotate('',
                xy=pos[edge[0]], 
                xytext=pos[edge[1]], 
                xycoords='data',
                textcoords='data',
                arrowprops=dict(arrowstyle="-", color='k',
                                linewidth=((np.exp(G.edges[edge]['weight']) - np.exp(0))/(np.exp(1) - np.exp(0)))*2.5+0.5, 
                                alpha=0.2,
                                shrinkA=0.5, shrinkB=0.5,
                                patchA=None, patchB=None,
                                connectionstyle="arc3,rad=-0.1",),
                zorder=0,
                )
texts = []
# all 
for k in G.nodes():
    if moi[k][0] > p_threshold:
        weight='bold'
    else:
        weight='normal'
    texts.append(ax.text(pos[k][0], pos[k][1], k, size=9, weight=weight))
adjust_text(texts, arrowprops=dict(arrowstyle='-', color='k'), force_text=(0.12, 0.3))
fig.colorbar(im, ax=ax, label='-log10(P) between error groups')

# %%
savefigs = False

# %%
# plot
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
node_sizes = [G.nodes[n]['size'] for n in G.nodes()]
im = nx.draw_networkx_nodes(
    G, pos=pos, label=False,
    nodelist=G.nodes(),
    node_color=[G.nodes[n]['color'] for n in G.nodes()],
    node_size=range_scale(np.exp([G.nodes[n]['size'] for n in G.nodes()]), min_target=50, max_target=200),
    cmap='coolwarm',
    ax=ax)
for edge in G.edges:
    ax.annotate('',
                xy=pos[edge[0]], 
                xytext=pos[edge[1]], 
                xycoords='data',
                textcoords='data',
                arrowprops=dict(arrowstyle="-", color='k',
                                linewidth=((np.exp(G.edges[edge]['weight']) - np.exp(0))/(np.exp(1) - np.exp(0)))*2.5+0.5, 
                                alpha=0.2,
                                shrinkA=0.5, shrinkB=0.5,
                                patchA=None, patchB=None,
                                connectionstyle="arc3,rad=-0.1",),
                zorder=0,
                )
texts = []
# all 
for k in G.nodes():
    if moi[k][0] > p_threshold:
        weight='bold'
    else:
        weight='normal'
    texts.append(ax.text(pos[k][0], pos[k][1], k, size=9, weight=weight))
adjust_text(texts, arrowprops=dict(arrowstyle='-', color='k'), force_text=(0.12, 0.3))
fig.colorbar(im, ax=ax, label='-log10(P) between error groups')

if savefigs:
    fig.savefig(os.path.join(pfp, 'mdcorrnet_errgrpP_informativenessSize.pdf'), bbox_inches='tight')

# %%
# color by node
from wearables.scripts.aesthetics import md_node_annotation
# md_node_category_cmap = {k:'#'+v for k,v in zip(dt['cat'].value_counts().index, ["171a21","617073","7a93ac","92bceka","afb3f7","8db580","efd6ac","c44900"])}
from wearables.scripts.aesthetics import md_node_category_cmap

# %%
# update graph
for k in G.nodes:
    G.nodes[k]['size'] = moi[k][2] if not np.isnan(moi[k][2]) or np.isinf(moi[k][2]) else 0
    G.nodes[k]['color'] = moi[k][0]

# %%
# make a joint df for bar plotting

# %%
dt = pd.Series(md_node_annotation).reset_index().rename(columns={'index':'var', 0:'cat'})
dt['cat'].value_counts()
# Out:
# Comorbidities                    21
# Procedural                       17
# Pregnancy outcome                17
# Sleep-quality                    16
# Social determinants of health    14
# Activity-related                 14
# Depression-related               13
# Stress-related                   10
# Name: cat, dtype: int64

# %%
md_node_category_cmap = {
    'Pregnancy outcome': '#b0f2b4',
    'Comorbidities': '#baf2e9',
    'Sleep-quality': '#bad7f2',
    'Social determinants of health': '#f2bac9',
    'Activity-related': '#f2e2ba',
    'Depression-related': '#37393a',
    'Procedural': '#f991cc',
    'Stress-related': '#6d696a'
}

# %%
dt = dt.merge(pd.DataFrame(pd.DataFrame(moi).T.rename(columns={k:v for k,v in zip(list(range(3)), ['-log10P', 'AU-PRC', 'AU-PRC (%-diff)'])})), 
         left_on='var', right_index=True, how='left')

# %%
dtt = pd.DataFrame(columns=dt.columns)
for cat in dt.value_counts('cat').index:
    dtt = dtt.append(dt.loc[dt['cat']==cat, :].sort_values(by='-log10P', ascending=False), ignore_index=True)
dt = dtt 
del dtt

# %%
dt.head()
# Out:
#                        var            cat   -log10P    AU-PRC  AU-PRC (%-diff)
# 0             hypertension  Comorbidities  3.785418  0.669416         1.014579
# 1  pregestational_diabetes  Comorbidities  2.727432  0.666667         1.000088
# 2            other_disease  Comorbidities  2.563766  0.538430         0.614268
# 3            prior_ptb_all  Comorbidities  2.227092  0.200380         0.364778
# 4          fullterm_births  Comorbidities  1.587216  0.697014         0.381180

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 2.5))
sns.barplot(x='var', y='-log10P', data=dt, ax=ax, hue='cat', dodge=False, palette=md_node_category_cmap)
ax.set_xticks([])
ax.set_xlabel('')
ax.set_ylabel('-log10(P) between error groups')
ax.legend(bbox_to_anchor=(1.01, 1))

# %%
p_threshold
# Out:
# 1.3010299956639813

# %%
# seperate per grp 
fig = plt.figure(figsize=(10, 12))
for i, cat in enumerate(dt['cat'].unique()):
    ax = fig.add_subplot(4, 2, i+1)
    sns.barplot(x='var', y='-log10P', data=dt.loc[dt['cat']==cat], 
                                                  ax=ax, hue='cat', dodge=False, palette=md_node_category_cmap)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    ax.plot([*ax.get_xlim()], [p_threshold, p_threshold], 'k--', zorder=0)
    ax.set_xlabel('')
    ax.set_ylabel('')
    ax.set_title(cat)
    ax.legend().set_visible(False)
fig.tight_layout()
fig.savefig(os.path.join(pfp, 'barplot_pVvariables_by_cat.pdf'), bbox_inches='tight')

# %%
# actually, not the right name in the columns
dt = dt.rename(columns={'AU-PRC': 'AU-PRC or Rho', 'AU-PRC (%-diff)': '%-diff or MAPE'})
dt.head()
# Out:
#                        var            cat   -log10P  AU-PRC or Rho  \
# 0             hypertension  Comorbidities  3.785418       0.669416
# 1  pregestational_diabetes  Comorbidities  2.727432       0.666667
# 2            other_disease  Comorbidities  2.563766       0.538430
# 3            prior_ptb_all  Comorbidities  2.227092       0.200380
# 4          fullterm_births  Comorbidities  1.587216       0.697014
#
#    %-diff or MAPE
# 0        1.014579
# 1        1.000088
# 2        0.614268
# 3        0.364778
# 4        0.381180

# %%
# re-rank
dtt = pd.DataFrame(columns=dt.columns)
for cat in dt.value_counts('cat').index:
    dtt = dtt.append(dt.loc[dt['cat']==cat, :].sort_values(by='AU-PRC or Rho', ascending=False), ignore_index=True)
dt = dtt 
del dtt

# %%
dt.head()
# Out:
#                        var            cat   -log10P  AU-PRC or Rho  \
# 0                 bc_past1  Comorbidities  0.800944       0.930346
# 1              surghx_none  Comorbidities  0.097508       0.751211
# 2          fullterm_births  Comorbidities  1.587216       0.697014
# 3             hypertension  Comorbidities  3.785418       0.669416
# 4  pregestational_diabetes  Comorbidities  2.727432       0.666667
#
#    %-diff or MAPE
# 0        0.127801
# 1        0.307682
# 2        0.381180
# 3        1.014579
# 4        1.000088

# %%
dtt = dt.loc[dt['cat']==cat, :]
x, y, c = dtt['var'], dtt['AU-PRC or Rho'], dtt['%-diff or MAPE']

# %%
# seperate per grp 
fig = plt.figure(figsize=(10, 12))
for i, cat in enumerate(dt['cat'].unique()):
    ax = fig.add_subplot(4, 2, i+1)
    dtt = dt.loc[dt['cat']==cat, :]
    x, y, c = dtt['var'], dtt['AU-PRC or Rho'], dtt['%-diff or MAPE']
    im = ax.scatter(x, y, c=c, s=range_scale(c, min_target=10, max_target=100), vmin=0, vmax=1, cmap='RdYlBu_r')
    for ii in range(len(x)):
        ax.plot([x.iloc[ii], x.iloc[ii]], [0, y.iloc[ii]], 'k--', linewidth=0.5, zorder=0)
    ax.set_xticklabels(x, rotation=45, ha='right')
#     fig.colorbar(im, ax=ax, label='%-diff or MAPE')
    ax.set_ylabel("AU-PRC or Spearman's Rho")
    ax.set_ylim([0, 1.1])
    ax.set_yticks([0, 0.2, 0.4, 0.6, 0.8, 1])
    ax.set_title(cat)
fig.tight_layout()
fig.savefig(os.path.join(pfp, 'barplot_AUPRC-RhoVvars_by_cat.pdf'), bbox_inches='tight')
# Out:
# /tmp/ipykernel_2011525/2357509112.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x, rotation=45, ha='right')

# %%
# color corrnet by these groupings and size as informativeness

# %%
# update graph
for k in G.nodes:
    G.nodes[k]['size'] = moi[k][2] if not np.isnan(moi[k][2]) or np.isinf(moi[k][2]) else 0
    G.nodes[k]['color'] = md_node_category_cmap[dt.loc[dt['var']==k, 'cat'].item()]

# %%
savefigs = True

# %%
# plot
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
node_sizes = [G.nodes[n]['size'] for n in G.nodes()]
im = nx.draw_networkx_nodes(
    G, pos=pos, label=False,
    nodelist=G.nodes(),
    node_color=[G.nodes[n]['color'] for n in G.nodes()],
    node_size=range_scale(np.exp([G.nodes[n]['size'] for n in G.nodes()]), min_target=50, max_target=200),
#     cmap=md_node_category_cmap,
    ax=ax)
for edge in G.edges:
    ax.annotate('',
                xy=pos[edge[0]], 
                xytext=pos[edge[1]], 
                xycoords='data',
                textcoords='data',
                arrowprops=dict(arrowstyle="-", color='k',
                                linewidth=((np.exp(G.edges[edge]['weight']) - np.exp(0))/(np.exp(1) - np.exp(0)))*2.5+0.5, 
                                alpha=0.2,
                                shrinkA=0.5, shrinkB=0.5,
                                patchA=None, patchB=None,
                                connectionstyle="arc3,rad=-0.1",),
                zorder=0,
                )
texts = []
# all 
for k in G.nodes():
    if moi[k][0] > p_threshold:
        weight='bold'
    else:
        weight='normal'
    texts.append(ax.text(pos[k][0], pos[k][1], k, size=9, weight=weight, color=md_node_category_cmap[dt.loc[dt['var']==k, 'cat'].item()]))
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='k'), force_text=(0.12, 0.3))
# fig.colorbar(im, ax=ax, label='-log10(P) between error groups')

if savefigs:
    fig.savefig(os.path.join(pfp, 'mdcorrnet_cat_informativenessSize.pdf'), bbox_inches='tight')

# %% [markdown]
# # ptb specifics
#
# ## permutation tests per group
#
# ### (1) What actually is the difference?
# - put a number on the higher than actual group

# %%
md.head()
# Out:
#            record_id  age_enroll  marital  gestage_by  insur  ethnicity  race  \
# unique_id
# 2180_12         2180        34.0      1.0         1.0    3.0        0.0   0.0
# 2148_11         2148        34.0      1.0         2.0    3.0        0.0   0.0
# 1062_8          1062        31.0      0.0         1.0    5.0        0.0   1.0
# 1306_7          1306        25.0      0.0         3.0    5.0        0.0   1.0
# 2003_7          2003        38.0      1.0         1.0    1.0        0.0   1.0
#
#             bmi_1vis  prior_ptb_all  fullterm_births  ...  PQSI       KPAS  \
# unique_id                                             ...
# 2180_12    31.732640            0.0              0.0  ...  10.0   9.053680
# 2148_11    22.406605            0.0              1.0  ...  11.0  10.266234
# 1062_8     40.106270            0.0              0.0  ...   8.0   9.493074
# 1306_7     24.555670            0.0              0.0  ...  10.0   8.889610
# 2003_7     37.804455            0.0              0.0  ...   8.0   8.984632
#
#            EpworthSS  Edinburgh  Pre-term birth     y       yhat  split  \
# unique_id
# 2180_12          5.0        6.0           False  12.0  11.777130  train
# 2148_11          9.0        7.0           False  11.0  18.814798  train
# 1062_8           3.0        5.0           False   8.0  14.428290  train
# 1306_7           9.0        9.0           False   7.0  16.641426  train
# 2003_7           8.0        3.0           False   7.0  20.953638   test
#
#                error         Error group
# unique_id
# 2180_12    -0.222870             lt10wks
# 2148_11     7.814798             lt10wks
# 1062_8      6.428290             lt10wks
# 1306_7      9.641426             lt10wks
# 2003_7     13.953638  Higher-than-actual
#
# [5 rows x 131 columns]

# %%
md['hypertension'].value_counts()
# Out:
# 0.0    2070
# 1.0     229
# 2.0       6
# Name: hypertension, dtype: int64

# %%
df['hypertension'] = df['hypertension'].astype('category')
df['Error group'] = df['Error group'].astype('category')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/wearables/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/miniconda3/envs/wearables/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/miniconda3/envs/wearables/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Error group'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1467669/3986255469.py in <module>
#       1 df['hypertension'] = df['hypertension'].astype('category')
# ----> 2 df['Error group'] = df['Error group'].astype('category')
#
# ~/miniconda3/envs/wearables/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# ~/miniconda3/envs/wearables/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Error group'

# %%
dt = df.sample(2)
dt.groupby(['Error group', 'hypertension']).size().unstack(fill_value=0)

# %%
def md_group_diffs(df, voi={'ptb_37wks': 'categorical',
                            'GA': 'continuous'}, 
                   groupby='Error group',
                   ratio_only=False,
                   out_file=None):
    
    def pd_chisq(df, feat, groupby='Error group'):
        from scipy.stats import chi2_contingency
        obs = df.groupby([groupby, feat]).size().unstack(fill_value=0)
        try:
            chi2, p, dof, expected = chi2_contingency(obs)
        except ValueError:
            chi2, p, dof, expected = chi2_contingency(obs + 1) # add fake observation to avoid 0s
        return p, obs, expected
    
    def pd_kruskalwallis(df, feat, groupby='Error group'):
        from scipy.stats import kruskal
        size = []
        for i, g in enumerate(df[groupby].unique()):
            dt = df.loc[df[groupby]==g, feat].to_numpy()
            size.append(dt.shape[0])
            if i==0:
                X = dt
            else:
                X = np.concatenate((X, dt))
        X = np.split(X, np.cumsum(size[:-1]))
        statistic, p = kruskal(*X)
        return p
    
    # main block
    results = {g: {} for g in voi.keys()}
    for g, dtype in voi.items():

        if dtype == 'categorical':
            p, obs, expected = pd_chisq(df, g, groupby=groupby)
            expected = pd.DataFrame(expected, 
                                    index=obs.index.to_list(), 
                                    columns=obs.columns.to_list())
            total_obs = sum([v2 for k,v1 in obs.to_dict().items() for v2 in v1.values()])
            total_exp = sum([v2 for k,v1 in expected.to_dict().items() for v2 in v1.values()])
            p_obs = obs.to_dict()
            p_exp = expected.to_dict()
            for k in p_obs.keys():
                p_obs[k] = {k:v/total_obs for k,v in p_obs[k].items()}
                p_exp[k] = {k:v/total_exp for k,v in p_exp[k].items()}
            results[g] = {'Variable': g, 'P': p, 
                   'Tasktype': 'Classification', 
                   'Observed': obs.to_dict(),
                   'Expected': expected.to_dict(),
                   'pObserved': p_obs, 
                   'pExpected': p_exp,}
        else:
            p = pd_kruskalwallis(df, g, groupby=groupby)
            results[g] = {
                'Variable': g, 'P': p,
                'Tasktype': 'Classification', 
                'Observed': {'q{}'.format(i):df.groupby(groupby)[g].quantile(i).to_dict() for i in [0.25, 0.5, 0.75]},
                'Expected': {'q{}'.format(i):df[g].quantile(i) for i in [0.25, 0.5, 0.75]},
                'log2_grpVall' : {str(gg):np.log2(df.loc[df[groupby]==gg, g].mean()) - np.log2(df[g].mean()) for gg in df[groupby].unique()},
            }
    return results


def sample_metric(df, 
                  voi={'ptb_37wks': 'categorical','GA': 'continuous'}, 
                  value=None, n_samples=200, groupby='Error group'):
    '''ratio of obs/expected

    Arguments:
      value (dict): [optional, Default=None] provide dict with value to select from col of table
    '''
    import random
    df = df.copy(deep=True)
    df[groupby] = df[groupby].astype('category') # to ensure unique val not lost in small sample
    for k, v in voi.items():
        if v == 'categorical':
            df[k] = df[k].astype('category') # to ensure unique val not lost in small sample
    dt = df.sample(n_samples, replace=True)
    grp = dt[groupby].to_list()
    random.shuffle(grp)
    dt['{}_shuffled'.format(groupby)] = grp
    results = {k: {} for k in voi.keys()}
    for i, (k, dtype) in enumerate(voi.items()):
        sub_res = md_group_diffs(dt, {k:voi[k]}, groupby=groupby)[k]
        sub_res_null = md_group_diffs(dt, {k:voi[k]}, groupby='{}_shuffled'.format(groupby))[k]
        if dtype=='categorical':
            # obs
            obs = pd.DataFrame(sub_res['pObserved'])
            exp = pd.DataFrame(sub_res['pExpected'])
            factor = obs/exp
            # null
            obs_null = pd.DataFrame(sub_res_null['pObserved'])
            exp_null = pd.DataFrame(sub_res_null['pExpected'])
            factor_null = obs_null/exp_null
            if value is None:
                idx = np.unravel_index(np.argmax((factor - 1).abs().to_numpy()), factor.shape)
                results[k] = factor[idx[1]].to_dict()
                results['{}_null'.format(k)] = factor_null[idx[1]].to_dict()
            else:
                results[k] = factor[value[k]].to_dict()
                results['{}_null'.format(k)] = factor_null[value[k]].to_dict()
        elif dtype=='continuous':
            results[k] = sub_res['log2_grpVall']
            results['{}_null'.format(k)] = sub_res_null['log2_grpVall']
        else:
            print('wrong dtype specified in voi')
    return results

# %%
# we need to define a function 
#   that will grab the maximum value observed in the training data
#   then print out that to use in the future (port it to aesthetics)

def get_max_value(df, 
                  voi={'ptb_37wks': 'categorical','GA': 'continuous'},
                  groupby='Error group'):
    value = {}
    for i, (k, dtype) in enumerate(voi.items()):
        sub_res = md_group_diffs(df, {k:voi[k]}, groupby=groupby)[k]
        if dtype=='categorical':
            # obs
            obs = pd.DataFrame(sub_res['pObserved'])
            exp = pd.DataFrame(sub_res['pExpected'])
            factor = obs/exp

            idx = np.unravel_index(np.argmax((factor - 1).abs().to_numpy()), factor.shape)
            value[k] = factor[idx[1]].name
        else:
            continue
    return value

# %%
max_categorical_obsVexp_ratio = get_max_value(md, mdpred_voi) # from wearables.scripts.aesthetics import max_categorical_obsVexp_ratio
# Out:
# /tmp/ipykernel_1467669/2724408599.py:59: RuntimeWarning: invalid value encountered in log2
#   'log2_grpVall' : {str(gg):np.log2(df.loc[df[groupby]==gg, g].mean()) - np.log2(df[g].mean()) for gg in df[groupby].unique()},

# %%
def md_grpdiff_perm_test(df, groupby='Error group',
                         voi={'ptb_37wks': 'categorical'}, 
                         value=None,
                         n_trials=1000,
                         verbose=True, 
                         dataframe=False):
    '''
    Arguments:
      dataframe (bool): [optional, Default=False] return as dataframe? If not, returns dict
      
    '''
    if verbose:
        t_total = time.time()
    results = {k: {} for k in list(voi.keys()) + ['{}_null'.format(kk) for kk in voi.keys()]} # {k: {g: [] for g in df[groupby].unique()} for k in voi.keys()}
    if value is None:
        value_tmp = {}
    for i, (v, dtype) in enumerate(voi.items()):
        for n in range(n_trials):
            if value is None and dtype=='categorical':
                if n==0:
                    value_tmp[v] = get_max_value(df, {v:voi[v]}, groupby=groupby)[v]
                    print('\nvalue used for {}={}\n'.format(v, value_tmp[v]))
                m_n = sample_metric(df, {v:voi[v]}, value=value_tmp, groupby=groupby)
            else:
                m_n = sample_metric(df, {v:voi[v]}, value=value, groupby=groupby)
            for key in m_n.keys():
                for kk, val in m_n[key].items():
                    if n==0:
                        results[key][kk] = [val] 
                    else:
                        results[key][kk].append(val)
            if verbose and n % 100 == 0:
                print(f"through n={n+1} trials and i={i+1} var of {len(list(voi.keys()))} in {time.time()-t_total:.0f}-s")
    if verbose:
        print('\nResults:')
        for k in results.keys():
            print(f"  {k}:")
            for kk, vv in results[k].items():
                print(f"    {kk}\t{np.mean(vv):.2f}")
                
    if dataframe:
        # bar plot from this
        dt = pd.DataFrame()
        for k in results.keys():
            dtt = pd.DataFrame()
            for kk, vv in results[k].items():
                dtt[kk] = vv
            dtt['var'] = k if 'null' not in k else k.split('_null')[0]
            if 'null' in k:
                dtt['dist'] = 'Null'
            else:
                dtt['dist'] = 'Obs'
            dt = dt.append(dtt)
            del dtt
        dt = dt.melt(id_vars=['var', 'dist'], value_name='Ratio', var_name=groupby)
        return dt
    else:
        return results

# %%
res = md_grpdiff_perm_test(md.loc[md['split']=='train'], voi={'ptb_37wks': 'categorical'}, value=max_categorical_obsVexp_ratio, verbose=True)
# Out:
# through n=1 trials and i=1 var of 1 in 0-s
# through n=101 trials and i=1 var of 1 in 1-s
# through n=201 trials and i=1 var of 1 in 2-s
# through n=301 trials and i=1 var of 1 in 3-s
# through n=401 trials and i=1 var of 1 in 4-s
# through n=501 trials and i=1 var of 1 in 5-s
# through n=601 trials and i=1 var of 1 in 5-s
# through n=701 trials and i=1 var of 1 in 6-s
# through n=801 trials and i=1 var of 1 in 7-s
# through n=901 trials and i=1 var of 1 in 8-s
#
# Results:
#   ptb_37wks:
#     Higher-than-actual	1.33
#     Lower-than-actual	0.49
#     lt10wks	1.07
#   ptb_37wks_null:
#     Higher-than-actual	1.00
#     Lower-than-actual	0.98
#     lt10wks	1.00

# %%
from scipy.stats import ttest_ind

# %%
voi={'ptb_37wks': 'categorical'}
for k in voi.keys():
    for kk in ['Higher-than-actual', 'Lower-than-actual', 'lt10wks']:
        a = res[k][kk]
        b = res['{}_null'.format(k)][kk]
        statistic, p = ttest_ind(a, b, equal_var=False)
        print(f"{kk}\tP={p:.2e}({wearutils.p_encoder(p)})")
# Out:
# Higher-than-actual	P=2.29e-27(***)
# Lower-than-actual	P=1.40e-152(***)
# lt10wks	P=4.57e-41(***)

# %% [markdown]
# ### (2) Is that difference consistent in the test group?

# %%
res_tst = md_grpdiff_perm_test(md.loc[md['split']=='test'], voi={'ptb_37wks': 'categorical'}, value=max_categorical_obsVexp_ratio, verbose=True)
# Out:
# through n=1 trials and i=1 var of 1 in 0-s
# through n=101 trials and i=1 var of 1 in 1-s
# through n=201 trials and i=1 var of 1 in 1-s
# through n=301 trials and i=1 var of 1 in 2-s
# through n=401 trials and i=1 var of 1 in 2-s
# through n=501 trials and i=1 var of 1 in 3-s
# through n=601 trials and i=1 var of 1 in 3-s
# through n=701 trials and i=1 var of 1 in 4-s
# through n=801 trials and i=1 var of 1 in 4-s
# through n=901 trials and i=1 var of 1 in 5-s
#
# Results:
#   ptb_37wks:
#     Higher-than-actual	1.63
#     Lower-than-actual	0.42
#     lt10wks	1.04
#   ptb_37wks_null:
#     Higher-than-actual	1.04
#     Lower-than-actual	0.99
#     lt10wks	1.00

# %% [markdown]
# ## (1) & (2) visualize

# %%
# bar plot from this
dt = pd.DataFrame()
for k in res.keys():
    dtt = pd.DataFrame()
    for kk, vv in res[k].items():
        dtt[kk] = vv
    dtt['var'] = k if 'null' not in k else k.split('_null')[0]
    if 'null' in k:
        dtt['dist'] = 'Null'
    else:
        dtt['dist'] = 'Obs'
    dt = dt.append(dtt)
    del dtt
dt = dt.melt(id_vars=['var', 'dist'], value_name='Ratio', var_name='Error group')

# %%
# # add tst stuff
# dt = pd.DataFrame()
# for k in res.keys():
#     dtt = pd.DataFrame()
#     for kk, vv in res[k].items():
#         dtt[kk] = vv
#     dtt['var'] = k if 'null' not in k else k.split('_null')[0]
#     if 'null' in k:
#         dtt['dist'] = 'Null'
#     else:
#         dtt['dist'] = 'Obs'
#     dtt['split'] = 'train'
#     dt = dt.append(dtt)
#     del dtt
# for k in res_tst.keys():
#     dtt = pd.DataFrame()
#     for kk, vv in res_tst[k].items():
#         dtt[kk] = vv
#     dtt['var'] = k if 'null' not in k else k.split('_null')[0]
#     if 'null' in k:
#         dtt['dist'] = 'Null'
#     else:
#         dtt['dist'] = 'Obs'
#     dtt['split'] = 'test'
#     dt = dt.append(dtt)
#     del dtt
# dt = dt.melt(id_vars=['var', 'dist', 'split'], value_name='Ratio', var_name='Error group')

# %%
dist_cmap = {'Null': '#2F5061', 'Obs': '#E57F84'}

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 2))
sns.barplot(x='Error group', y='Ratio', hue='dist', data=dt, palette=dist_cmap, ax=ax, linewidth=3)
ax.plot([*ax.get_xlim()], [1.0, 1.0], 'k--', linewidth=0.8, zorder=0)
ax.legend().set_visible(False)
ax.set_xlabel('')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
ax.set_title('Prevalence of pre-term birth (train set)')
# Out:
# Text(0.5, 1.0, 'Prevalence of pre-term birth (train set)')

# %%
# g = sns.FacetGrid(dt, row='split', aspect=2)
# g.map_dataframe(sns.barplot, x='Error group', y='Ratio', hue='dist', palette=dist_cmap, dodge=True)
# for ax in g.axes.flat:
#     ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# %%
savefigs = True

# %%
a = res['ptb_37wks']['Higher-than-actual']
b = res['ptb_37wks']['lt10wks']
ttest_ind(a, b, equal_var=False)
# Out:
# Ttest_indResult(statistic=8.487459153527896, pvalue=7.131368254763238e-17)

# %%
list(dist_cmap.values())*3
# Out:
# ['#2F5061', '#E57F84', '#2F5061', '#E57F84', '#2F5061', '#E57F84']

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 2))
sns.stripplot(x='Error group', y='Ratio', 
              hue='dist', data=dt, 
              palette=dist_cmap, ax=ax, linewidth=0, 
              dodge=True, zorder=1, s=2, 
              alpha=0.6, rasterized=True)
sns.barplot(x='Error group', y='Ratio', hue='dist', data=dt, palette=dist_cmap, 
            ax=ax, zorder=2, facecolor='none', edgecolor='gray', linewidth=2, ci='sd', errwidth=3, errcolor='gray')
#             boxprops={'facecolor':'none','edgecolor':'k'})
ax.plot([*ax.get_xlim()], [1.0, 1.0], 'k--', linewidth=0.8, zorder=0)
ax.legend().set_visible(False)
ax.set_xlabel('')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
ax.set_title('Prevalence of pre-term birth (train set)')
if savefigs:
    fig.savefig(os.path.join(pfp, 'boxplot_ratioVerrgrp_permtest_train.pdf'), bbox_inches='tight', dpi=600)

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 2))
sns.stripplot(x='Error group', y='Ratio', 
              hue='dist', data=dt, 
              palette=dist_cmap, ax=ax, linewidth=0, 
              dodge=True, zorder=1, s=2, 
              alpha=0.6, rasterized=True)
sns.boxplot(x='Error group', y='Ratio', hue='dist', data=dt, palette=dist_cmap, ax=ax, linewidth=1, zorder=2, 
            boxprops={'facecolor':'none','edgecolor':'k'}, showfliers=False)
ax.plot([*ax.get_xlim()], [1.0, 1.0], 'k--', linewidth=0.8, zorder=0)
ax.legend().set_visible(False)
ax.set_xlabel('')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
ax.set_title('Prevalence of pre-term birth (train set)')
if savefigs:
    fig.savefig(os.path.join(pfp, 'boxplot_ratioVerrgrp_permtest_train.pdf'), bbox_inches='tight', dpi=600)

# %%
# bar plot from this
dt = pd.DataFrame()
for k in res_tst.keys():
    dtt = pd.DataFrame()
    for kk, vv in res_tst[k].items():
        dtt[kk] = vv
    dtt['var'] = k if 'null' not in k else k.split('_null')[0]
    if 'null' in k:
        dtt['dist'] = 'Null'
    else:
        dtt['dist'] = 'Obs'
    dt = dt.append(dtt)
    del dtt
dt = dt.melt(id_vars=['var', 'dist'], value_name='Ratio', var_name='Error group')

fig, ax = plt.subplots(1, 1, figsize=(5, 2))
sns.stripplot(x='Error group', y='Ratio', 
              hue='dist', data=dt, 
              palette=dist_cmap, ax=ax, linewidth=0, 
              dodge=True, zorder=1, s=2, 
              alpha=0.6, rasterized=True)
sns.boxplot(x='Error group', y='Ratio', hue='dist', data=dt, palette=dist_cmap, ax=ax, linewidth=1, zorder=2, 
            boxprops={'facecolor':'none','edgecolor':'k'}, showfliers=False)
ax.plot([*ax.get_xlim()], [1.0, 1.0], 'k--', linewidth=0.8, zorder=0)
ax.legend().set_visible(False)
ax.set_xlabel('')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
ax.set_title('Prevalence of pre-term birth (test set)')
if savefigs:
    fig.savefig(os.path.join(pfp, 'boxplot_ratioVerrgrp_permtest_test.pdf'), bbox_inches='tight', dpi=600)

# %%
res['ptb_37wks'].keys()
# Out:
# dict_keys(['Higher-than-actual', 'Lower-than-actual', 'lt10wks'])

# %%
from scipy.stats import ttest_ind
from scipy.stats import mannwhitneyu

# %%
a = dt.loc[(dt['dist']=='Obs') & (dt['Error group']=='lt10wks'), 'Ratio']
b = dt.loc[(dt['dist']=='Null') & (dt['Error group']=='lt10wks'), 'Ratio']
mannwhitneyu(a, b)
# Out:
# MannwhitneyuResult(statistic=348230.5, pvalue=3.40576851774646e-32)

# %%
a = dt.loc[(dt['dist']=='Obs') & (dt['Error group']=='Lower-than-actual'), 'Ratio']
b = dt.loc[(dt['dist']=='Null') & (dt['Error group']=='Lower-than-actual'), 'Ratio']
mannwhitneyu(a, b)
# Out:
# MannwhitneyuResult(statistic=241154.0, pvalue=1.0681119349514176e-89)

# %%
fig, ax = plt.subplots(1, 1, figsize=(3, 2))
sns.distplot(dt.loc[(dt['dist']=='Obs') & (dt['Error group']=='Lower-than-actual'), 'Ratio'], color=dist_cmap['Obs'], ax=ax)
sns.distplot(dt.loc[(dt['dist']=='Null') & (dt['Error group']=='Lower-than-actual'), 'Ratio'], color=dist_cmap['Null'], ax=ax)
ax.set_title('Lower-than-actual GA')
a = res['ptb_37wks']['Lower-than-actual']
b = res['ptb_37wks_null']['Lower-than-actual']
print(mannwhitneyu(a, b))
print('log2 FC:', np.log2(np.mean(a)) - np.log2(np.mean(b)))
if savefigs:
    fig.savefig(os.path.join(pfp, 'distplot_lowerthanactual_obsVnull.pdf'), bbox_inches='tight')
# Out:
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# MannwhitneyuResult(statistic=241154.0, pvalue=1.0681119349514176e-89)
# log2 FC: -0.7688339373315008

# %%
fig, ax = plt.subplots(1, 1, figsize=(3, 2))
sns.distplot(dt.loc[(dt['dist']=='Obs') & (dt['Error group']=='Higher-than-actual'), 'Ratio'], color=dist_cmap['Obs'], ax=ax)
sns.distplot(dt.loc[(dt['dist']=='Null') & (dt['Error group']=='Higher-than-actual'), 'Ratio'], color=dist_cmap['Null'], ax=ax)
ax.set_title('Higher-than-actual GA')
a = res['ptb_37wks']['Higher-than-actual']
b = res['ptb_37wks_null']['Higher-than-actual']
print(mannwhitneyu(a, b))
print('log2 FC:', np.log2(np.mean(a)) - np.log2(np.mean(b)))
if savefigs:
    fig.savefig(os.path.join(pfp, 'distplot_Higherthanactual_obsVnull.pdf'), bbox_inches='tight')
# Out:
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/ngrav/miniconda3/envs/wearables/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# MannwhitneyuResult(statistic=411354.0, pvalue=3.295803046214661e-12)
# log2 FC: 0.2502915447219244

# %% [markdown]
# ### (3) Is the difference statistically significant?
# - permutation test

# %%
# shown above

# %% [markdown]
# ### (4) what other interesting differences are there and how can we automate this process into a pipeline for risk assessment?

# %%
# plot all significant and simulate them, show with barplots

# order by 
dt = pd.Series(md_node_annotation).reset_index().rename(columns={'index':'var', 0:'cat'})
dt['cat'].value_counts()
dt = dt.merge(pd.DataFrame(pd.DataFrame(moi).T.rename(columns={k:v for k,v in zip(list(range(3)), ['-log10P', 'AU-PRC', 'AU-PRC (%-diff)'])})), 
         left_on='var', right_index=True, how='left')
dtt = pd.DataFrame(columns=dt.columns)
for cat in dt.value_counts('cat').index:
    dtt = dtt.append(dt.loc[dt['cat']==cat, :].sort_values(by='-log10P', ascending=False), ignore_index=True)
dt = dtt 
del dtt

# %%
sig_voi_cat = {}
sig_voi_cont = {}
for i in dt.index:
    if dt.loc[i, '-log10P'] >= -1*np.log10(0.01):#p_threshold:
        if mdpred_voi[dt.loc[i, 'var']] == 'continuous':
            sig_voi_cont[dt.loc[i, 'var']] = mdpred_voi[dt.loc[i, 'var']]
        else:
            sig_voi_cat[dt.loc[i, 'var']] = mdpred_voi[dt.loc[i, 'var']]
del sig_voi_cat['ptb_37wks']

# %%
res_cont = md_grpdiff_perm_test(md.loc[md['split']=='train'], voi=sig_voi_cont, value=max_categorical_obsVexp_ratio, verbose=True)
# Out:
# through n=1 trials and i=1 var of 5 in 0-s
# through n=101 trials and i=1 var of 5 in 1-s
# through n=201 trials and i=1 var of 5 in 2-s
# through n=301 trials and i=1 var of 5 in 3-s
# through n=401 trials and i=1 var of 5 in 4-s
# through n=501 trials and i=1 var of 5 in 5-s
# through n=601 trials and i=1 var of 5 in 6-s
# through n=701 trials and i=1 var of 5 in 7-s
# through n=801 trials and i=1 var of 5 in 8-s
# through n=901 trials and i=1 var of 5 in 9-s
# through n=1 trials and i=2 var of 5 in 10-s
# through n=101 trials and i=2 var of 5 in 11-s
# through n=201 trials and i=2 var of 5 in 12-s
# through n=301 trials and i=2 var of 5 in 13-s
# through n=401 trials and i=2 var of 5 in 14-s
# through n=501 trials and i=2 var of 5 in 15-s
# through n=601 trials and i=2 var of 5 in 16-s
# through n=701 trials and i=2 var of 5 in 16-s
# through n=801 trials and i=2 var of 5 in 17-s
# through n=901 trials and i=2 var of 5 in 18-s
# through n=1 trials and i=3 var of 5 in 19-s
# through n=101 trials and i=3 var of 5 in 20-s
# through n=201 trials and i=3 var of 5 in 21-s
# through n=301 trials and i=3 var of 5 in 22-s
# through n=401 trials and i=3 var of 5 in 23-s
# through n=501 trials and i=3 var of 5 in 24-s
# through n=601 trials and i=3 var of 5 in 25-s
# through n=701 trials and i=3 var of 5 in 26-s
# through n=801 trials and i=3 var of 5 in 27-s
# through n=901 trials and i=3 var of 5 in 28-s
# through n=1 trials and i=4 var of 5 in 29-s
# through n=101 trials and i=4 var of 5 in 30-s
# through n=201 trials and i=4 var of 5 in 31-s
# through n=301 trials and i=4 var of 5 in 32-s
# through n=401 trials and i=4 var of 5 in 33-s
# through n=501 trials and i=4 var of 5 in 34-s
# through n=601 trials and i=4 var of 5 in 35-s
# through n=701 trials and i=4 var of 5 in 36-s
# through n=801 trials and i=4 var of 5 in 37-s
# through n=901 trials and i=4 var of 5 in 38-s
# through n=1 trials and i=5 var of 5 in 39-s
# through n=101 trials and i=5 var of 5 in 40-s
# through n=201 trials and i=5 var of 5 in 41-s
# through n=301 trials and i=5 var of 5 in 42-s
# through n=401 trials and i=5 var of 5 in 43-s
# through n=501 trials and i=5 var of 5 in 44-s
# through n=601 trials and i=5 var of 5 in 45-s
# through n=701 trials and i=5 var of 5 in 46-s
# through n=801 trials and i=5 var of 5 in 47-s
# through n=901 trials and i=5 var of 5 in 48-s
#
# Results:
#   infant_length:
#     Higher-than-actual	-0.02
#     lt10wks	-0.00
#     Lower-than-actual	0.01
#   head_circ:
#     lt10wks	-0.00
#     Lower-than-actual	0.01
#     Higher-than-actual	-0.01
#   ven_pco2:
#     lt10wks	-0.00
#     Higher-than-actual	0.03
#     Lower-than-actual	-0.01
#   ven_ph:
#     Higher-than-actual	-0.00
#     lt10wks	0.00
#     Lower-than-actual	0.00
#   ave_logpseudocount_wknd:
#     Lower-than-actual	-0.09
#     lt10wks	0.01
#     Higher-than-actual	0.04
#   infant_length_null:
#     Higher-than-actual	-0.00
#     lt10wks	-0.00
#     Lower-than-actual	0.00
#   head_circ_null:
#     Lower-than-actual	-0.00
#     lt10wks	0.00
#     Higher-than-actual	-0.00
#   ven_pco2_null:
#     lt10wks	0.00
#     Higher-than-actual	-0.00
#     Lower-than-actual	-0.00
#   ven_ph_null:
#     lt10wks	-0.00
#     Higher-than-actual	0.00
#     Lower-than-actual	-0.00
#   ave_logpseudocount_wknd_null:
#     lt10wks	-0.00
#     Lower-than-actual	-0.00
#     Higher-than-actual	-0.02

# %%
res_cat = md_grpdiff_perm_test(md.loc[md['split']=='train'], voi=sig_voi_cat, value=max_categorical_obsVexp_ratio, verbose=True)
# Out:
# through n=1 trials and i=1 var of 19 in 0-s
# through n=101 trials and i=1 var of 19 in 1-s
# through n=201 trials and i=1 var of 19 in 2-s
# through n=301 trials and i=1 var of 19 in 3-s
# through n=401 trials and i=1 var of 19 in 4-s
# through n=501 trials and i=1 var of 19 in 5-s
# through n=601 trials and i=1 var of 19 in 6-s
# through n=701 trials and i=1 var of 19 in 7-s
# through n=801 trials and i=1 var of 19 in 7-s
# through n=901 trials and i=1 var of 19 in 8-s
# through n=1 trials and i=2 var of 19 in 9-s
# through n=101 trials and i=2 var of 19 in 10-s
# through n=201 trials and i=2 var of 19 in 11-s
# through n=301 trials and i=2 var of 19 in 12-s
# through n=401 trials and i=2 var of 19 in 13-s
# through n=501 trials and i=2 var of 19 in 14-s
# through n=601 trials and i=2 var of 19 in 15-s
# through n=701 trials and i=2 var of 19 in 16-s
# through n=801 trials and i=2 var of 19 in 17-s
# through n=901 trials and i=2 var of 19 in 18-s
# through n=1 trials and i=3 var of 19 in 19-s
# through n=101 trials and i=3 var of 19 in 20-s
# through n=201 trials and i=3 var of 19 in 21-s
# through n=301 trials and i=3 var of 19 in 21-s
# through n=401 trials and i=3 var of 19 in 22-s
# through n=501 trials and i=3 var of 19 in 23-s
# through n=601 trials and i=3 var of 19 in 24-s
# through n=701 trials and i=3 var of 19 in 25-s
# through n=801 trials and i=3 var of 19 in 26-s
# through n=901 trials and i=3 var of 19 in 27-s
# through n=1 trials and i=4 var of 19 in 28-s
# through n=101 trials and i=4 var of 19 in 29-s
# through n=201 trials and i=4 var of 19 in 30-s
# through n=301 trials and i=4 var of 19 in 30-s
# through n=401 trials and i=4 var of 19 in 31-s
# through n=501 trials and i=4 var of 19 in 32-s
# through n=601 trials and i=4 var of 19 in 33-s
# through n=701 trials and i=4 var of 19 in 34-s
# through n=801 trials and i=4 var of 19 in 35-s
# through n=901 trials and i=4 var of 19 in 35-s
# through n=1 trials and i=5 var of 19 in 36-s
# through n=101 trials and i=5 var of 19 in 37-s
# through n=201 trials and i=5 var of 19 in 38-s
# through n=301 trials and i=5 var of 19 in 39-s
# through n=401 trials and i=5 var of 19 in 40-s
# through n=501 trials and i=5 var of 19 in 40-s
# through n=601 trials and i=5 var of 19 in 41-s
# through n=701 trials and i=5 var of 19 in 42-s
# through n=801 trials and i=5 var of 19 in 43-s
# through n=901 trials and i=5 var of 19 in 44-s
# through n=1 trials and i=6 var of 19 in 45-s
# through n=101 trials and i=6 var of 19 in 45-s
# through n=201 trials and i=6 var of 19 in 46-s
# through n=301 trials and i=6 var of 19 in 47-s
# through n=401 trials and i=6 var of 19 in 48-s
# through n=501 trials and i=6 var of 19 in 49-s
# through n=601 trials and i=6 var of 19 in 50-s
# through n=701 trials and i=6 var of 19 in 50-s
# through n=801 trials and i=6 var of 19 in 51-s
# through n=901 trials and i=6 var of 19 in 52-s
# through n=1 trials and i=7 var of 19 in 53-s
# through n=101 trials and i=7 var of 19 in 54-s
# through n=201 trials and i=7 var of 19 in 55-s
# through n=301 trials and i=7 var of 19 in 56-s
# through n=401 trials and i=7 var of 19 in 57-s
# through n=501 trials and i=7 var of 19 in 58-s
# through n=601 trials and i=7 var of 19 in 59-s
# through n=701 trials and i=7 var of 19 in 60-s
# through n=801 trials and i=7 var of 19 in 61-s
# through n=901 trials and i=7 var of 19 in 62-s
# through n=1 trials and i=8 var of 19 in 63-s
# through n=101 trials and i=8 var of 19 in 63-s
# through n=201 trials and i=8 var of 19 in 64-s
# through n=301 trials and i=8 var of 19 in 65-s
# through n=401 trials and i=8 var of 19 in 66-s
# through n=501 trials and i=8 var of 19 in 67-s
# through n=601 trials and i=8 var of 19 in 68-s
# through n=701 trials and i=8 var of 19 in 68-s
# through n=801 trials and i=8 var of 19 in 69-s
# through n=901 trials and i=8 var of 19 in 70-s
# through n=1 trials and i=9 var of 19 in 71-s
# through n=101 trials and i=9 var of 19 in 72-s
# through n=201 trials and i=9 var of 19 in 73-s
# through n=301 trials and i=9 var of 19 in 74-s
# through n=401 trials and i=9 var of 19 in 75-s
# through n=501 trials and i=9 var of 19 in 76-s
# through n=601 trials and i=9 var of 19 in 77-s
# through n=701 trials and i=9 var of 19 in 78-s
# through n=801 trials and i=9 var of 19 in 79-s
# through n=901 trials and i=9 var of 19 in 80-s
# through n=1 trials and i=10 var of 19 in 81-s
# through n=101 trials and i=10 var of 19 in 82-s
# through n=201 trials and i=10 var of 19 in 83-s
# through n=301 trials and i=10 var of 19 in 84-s
# through n=401 trials and i=10 var of 19 in 85-s
# through n=501 trials and i=10 var of 19 in 86-s
# through n=601 trials and i=10 var of 19 in 87-s
# through n=701 trials and i=10 var of 19 in 88-s
# through n=801 trials and i=10 var of 19 in 89-s
# through n=901 trials and i=10 var of 19 in 90-s
# through n=1 trials and i=11 var of 19 in 91-s
# through n=101 trials and i=11 var of 19 in 92-s
# through n=201 trials and i=11 var of 19 in 93-s
# through n=301 trials and i=11 var of 19 in 94-s
# through n=401 trials and i=11 var of 19 in 95-s
# through n=501 trials and i=11 var of 19 in 96-s
# through n=601 trials and i=11 var of 19 in 97-s
# through n=701 trials and i=11 var of 19 in 98-s
# through n=801 trials and i=11 var of 19 in 100-s
# through n=901 trials and i=11 var of 19 in 101-s
# through n=1 trials and i=12 var of 19 in 102-s
# through n=101 trials and i=12 var of 19 in 103-s
# through n=201 trials and i=12 var of 19 in 104-s
# through n=301 trials and i=12 var of 19 in 105-s
# through n=401 trials and i=12 var of 19 in 106-s
# through n=501 trials and i=12 var of 19 in 107-s
# through n=601 trials and i=12 var of 19 in 108-s
# through n=701 trials and i=12 var of 19 in 109-s
# through n=801 trials and i=12 var of 19 in 110-s
# through n=901 trials and i=12 var of 19 in 111-s
# through n=1 trials and i=13 var of 19 in 112-s
# through n=101 trials and i=13 var of 19 in 113-s
# through n=201 trials and i=13 var of 19 in 114-s
# through n=301 trials and i=13 var of 19 in 115-s
# through n=401 trials and i=13 var of 19 in 116-s
# through n=501 trials and i=13 var of 19 in 117-s
# through n=601 trials and i=13 var of 19 in 118-s
# through n=701 trials and i=13 var of 19 in 119-s
# through n=801 trials and i=13 var of 19 in 120-s
# through n=901 trials and i=13 var of 19 in 121-s
# through n=1 trials and i=14 var of 19 in 122-s
# through n=101 trials and i=14 var of 19 in 123-s
# through n=201 trials and i=14 var of 19 in 124-s
# through n=301 trials and i=14 var of 19 in 125-s
# through n=401 trials and i=14 var of 19 in 126-s
# through n=501 trials and i=14 var of 19 in 127-s
# through n=601 trials and i=14 var of 19 in 128-s
# through n=701 trials and i=14 var of 19 in 129-s
# through n=801 trials and i=14 var of 19 in 130-s
# through n=901 trials and i=14 var of 19 in 131-s
# through n=1 trials and i=15 var of 19 in 132-s
# through n=101 trials and i=15 var of 19 in 133-s
# through n=201 trials and i=15 var of 19 in 134-s
# through n=301 trials and i=15 var of 19 in 135-s
# through n=401 trials and i=15 var of 19 in 136-s
# through n=501 trials and i=15 var of 19 in 137-s
# through n=601 trials and i=15 var of 19 in 138-s
# through n=701 trials and i=15 var of 19 in 139-s
# through n=801 trials and i=15 var of 19 in 140-s
# through n=901 trials and i=15 var of 19 in 141-s
# through n=1 trials and i=16 var of 19 in 142-s
# through n=101 trials and i=16 var of 19 in 143-s
# through n=201 trials and i=16 var of 19 in 144-s
# through n=301 trials and i=16 var of 19 in 145-s
# through n=401 trials and i=16 var of 19 in 146-s
# through n=501 trials and i=16 var of 19 in 147-s
# through n=601 trials and i=16 var of 19 in 148-s
# through n=701 trials and i=16 var of 19 in 149-s
# through n=801 trials and i=16 var of 19 in 150-s
# through n=901 trials and i=16 var of 19 in 151-s
# through n=1 trials and i=17 var of 19 in 152-s
# through n=101 trials and i=17 var of 19 in 153-s
# through n=201 trials and i=17 var of 19 in 154-s
# through n=301 trials and i=17 var of 19 in 155-s
# through n=401 trials and i=17 var of 19 in 156-s
# through n=501 trials and i=17 var of 19 in 157-s
# through n=601 trials and i=17 var of 19 in 158-s
# through n=701 trials and i=17 var of 19 in 159-s
# through n=801 trials and i=17 var of 19 in 160-s
# through n=901 trials and i=17 var of 19 in 160-s
# through n=1 trials and i=18 var of 19 in 161-s
# through n=101 trials and i=18 var of 19 in 162-s
# through n=201 trials and i=18 var of 19 in 163-s
# through n=301 trials and i=18 var of 19 in 164-s
# through n=401 trials and i=18 var of 19 in 165-s
# through n=501 trials and i=18 var of 19 in 166-s
# through n=601 trials and i=18 var of 19 in 166-s
# through n=701 trials and i=18 var of 19 in 167-s
# through n=801 trials and i=18 var of 19 in 168-s
# through n=901 trials and i=18 var of 19 in 169-s
# through n=1 trials and i=19 var of 19 in 170-s
# through n=101 trials and i=19 var of 19 in 171-s
# through n=201 trials and i=19 var of 19 in 171-s
# through n=301 trials and i=19 var of 19 in 172-s
# through n=401 trials and i=19 var of 19 in 173-s
# through n=501 trials and i=19 var of 19 in 174-s
# through n=601 trials and i=19 var of 19 in 175-s
# through n=701 trials and i=19 var of 19 in 176-s
# through n=801 trials and i=19 var of 19 in 177-s
# through n=901 trials and i=19 var of 19 in 178-s
#
# Results:
#   hypertension:
#     Higher-than-actual	1.61
#     Lower-than-actual	0.00
#     lt10wks	1.13
#   pregestational_diabetes:
#     Higher-than-actual	1.51
#     Lower-than-actual	0.00
#     lt10wks	1.14
#   other_disease:
#     Higher-than-actual	1.74
#     Lower-than-actual	0.00
#     lt10wks	1.12
#   prior_ptb_all:
#     Higher-than-actual	1.36
#     Lower-than-actual	0.82
#     lt10wks	0.99
#   ppvisit_dx:
#     Higher-than-actual	1.22
#     Lower-than-actual	0.89
#     lt10wks	1.00
#   corticosteroids:
#     Higher-than-actual	0.97
#     Lower-than-actual	0.52
#     lt10wks	1.10
#   deliv_mode:
#     Higher-than-actual	2.05
#     Lower-than-actual	0.00
#     lt10wks	1.08
#   epidural:
#     Higher-than-actual	1.24
#     Lower-than-actual	0.78
#     lt10wks	1.02
#   gestage_by:
#     Higher-than-actual	1.45
#     Lower-than-actual	0.33
#     lt10wks	1.03
#   afterlunch1:
#     Higher-than-actual	1.68
#     Lower-than-actual	0.35
#     lt10wks	1.05
#   talking1:
#     Higher-than-actual	0.42
#     Lower-than-actual	1.67
#     lt10wks	0.82
#   reset1:
#     Higher-than-actual	2.20
#     Lower-than-actual	0.90
#     lt10wks	0.86
#   cartraffic1:
#     Higher-than-actual	1.65
#     Lower-than-actual	0.33
#     lt10wks	1.06
#   slp30_1trim:
#     Higher-than-actual	1.62
#     Lower-than-actual	0.32
#     lt10wks	1.07
#   slpwake_1trim:
#     Higher-than-actual	1.59
#     Lower-than-actual	0.30
#     lt10wks	1.07
#   tv1:
#     Higher-than-actual	1.62
#     Lower-than-actual	0.35
#     lt10wks	1.06
#   alcohol:
#     Higher-than-actual	1.54
#     Lower-than-actual	0.13
#     lt10wks	1.11
#   income_annual1:
#     Higher-than-actual	1.14
#     Lower-than-actual	1.20
#     lt10wks	0.94
#   smoke:
#     Higher-than-actual	1.40
#     Lower-than-actual	0.00
#     lt10wks	1.16
#   hypertension_null:
#     Higher-than-actual	1.09
#     Lower-than-actual	1.02
#     lt10wks	0.98
#   pregestational_diabetes_null:
#     Higher-than-actual	0.99
#     Lower-than-actual	0.97
#     lt10wks	1.00
#   other_disease_null:
#     Higher-than-actual	1.02
#     Lower-than-actual	0.98
#     lt10wks	1.00
#   prior_ptb_all_null:
#     Higher-than-actual	0.99
#     Lower-than-actual	0.98
#     lt10wks	1.00
#   ppvisit_dx_null:
#     Higher-than-actual	1.00
#     Lower-than-actual	1.00
#     lt10wks	1.00
#   corticosteroids_null:
#     Higher-than-actual	0.97
#     Lower-than-actual	1.01
#     lt10wks	1.00
#   deliv_mode_null:
#     Higher-than-actual	0.99
#     Lower-than-actual	1.00
#     lt10wks	1.00
#   epidural_null:
#     Higher-than-actual	1.01
#     Lower-than-actual	0.99
#     lt10wks	1.00
#   gestage_by_null:
#     Higher-than-actual	1.04
#     Lower-than-actual	0.90
#     lt10wks	0.96
#   afterlunch1_null:
#     Higher-than-actual	0.99
#     Lower-than-actual	1.03
#     lt10wks	1.00
#   talking1_null:
#     Higher-than-actual	0.85
#     Lower-than-actual	0.92
#     lt10wks	0.92
#   reset1_null:
#     Higher-than-actual	1.00
#     Lower-than-actual	0.91
#     lt10wks	1.01
#   cartraffic1_null:
#     Higher-than-actual	0.98
#     Lower-than-actual	0.98
#     lt10wks	1.00
#   slp30_1trim_null:
#     Higher-than-actual	1.06
#     Lower-than-actual	1.02
#     lt10wks	0.99
#   slpwake_1trim_null:
#     Higher-than-actual	1.02
#     Lower-than-actual	0.98
#     lt10wks	1.00
#   tv1_null:
#     Higher-than-actual	0.96
#     Lower-than-actual	1.02
#     lt10wks	1.00
#   alcohol_null:
#     Higher-than-actual	1.02
#     Lower-than-actual	1.01
#     lt10wks	1.00
#   income_annual1_null:
#     Higher-than-actual	0.98
#     Lower-than-actual	1.00
#     lt10wks	1.00
#   smoke_null:
#     Higher-than-actual	0.98
#     Lower-than-actual	0.97
#     lt10wks	1.01

# %%
# bar plot from this
dt = pd.DataFrame()
for k in res_cat.keys():
    dtt = pd.DataFrame()
    for kk, vv in res_cat[k].items():
        dtt[kk] = vv
    dtt['var'] = k if 'null' not in k else k.split('_null')[0]
    if 'null' in k:
        dtt['dist'] = 'Null'
    else:
        dtt['dist'] = 'Obs'
    dt = dt.append(dtt)
    del dtt
dt = dt.melt(id_vars=['var', 'dist'], value_name='Ratio', var_name='Error group')

g = sns.FacetGrid(dt, col='var', aspect=0.8, col_wrap=10)
g.map_dataframe(sns.stripplot, x='Error group', y='Ratio', hue='dist', palette=dist_cmap, dodge=True, rasterized=True, zorder=0, s=2)
# g.map_dataframe(sns.boxplot, x='Error group', y='Ratio', hue='dist', palette=dist_cmap, dodge=True, rasterized=True, boxprops={'facecolor':'none', 'edgecolor':'k'})
g.map_dataframe(sns.barplot, x='Error group', y='Ratio', hue='dist', palette=dist_cmap, dodge=True, errwidth=2, zorder=1, facecolor='none', edgecolor='k')
g.set_titles('{col_name}')
g.set(ylim=(0, 5))
for ax in g.axes.flat:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
g.savefig(os.path.join(pfp, 'barplots_sigvar_cat_permtests.pdf'), bbox_inches='tight')

# %%
# bar plot from this
dt = pd.DataFrame()
for k in res_cont.keys():
    dtt = pd.DataFrame()
    for kk, vv in res_cont[k].items():
        dtt[kk] = vv
    dtt['var'] = k if 'null' not in k else k.split('_null')[0]
    if 'null' in k:
        dtt['dist'] = 'Null'
    else:
        dtt['dist'] = 'Obs'
    dt = dt.append(dtt)
    del dtt
dt = dt.melt(id_vars=['var', 'dist'], value_name='Ratio', var_name='Error group')

g = sns.FacetGrid(dt, col='var', aspect=0.8, col_wrap=10)
g.map_dataframe(sns.stripplot, x='Error group', y='Ratio', hue='dist', palette=dist_cmap, dodge=True, rasterized=True, zorder=0, s=2)
g.map_dataframe(sns.barplot, x='Error group', y='Ratio', hue='dist', palette=dist_cmap, dodge=True, errwidth=2, zorder=1, facecolor='none', edgecolor='k')
g.set_titles('{col_name}')
for ax in g.axes.flat:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
g.savefig(os.path.join(pfp, 'barplots_sigvar_cont_permtests.pdf'), bbox_inches='tight')

# %% [markdown]
# # extract pvals
#
# For writing, need more pvals... extract quickly w/minimal regeneration

# %%
pfp = '/home/ngrav/project/wearables/results/'
savefigs = True

# %%
# load md info
from wearables.scripts.md_specification import mdpred_voi
from wearables.scripts.aesthetics import md_node_annotation

# filepaths to bst or pre-processed md with calculated metrics 
pp_md_fp = os.path.join(pfp, 'md_v522_220124.csv')

# load up to date md
md = pd.read_csv(pp_md_fp, index_col=0)

threshold = 10
md['Error group'] = 'lt{}wks'.format(threshold)
md.loc[(md['error'] >= threshold), 'Error group'] = 'Higher-than-actual'
md.loc[(md['error'] <= -threshold), 'Error group'] = 'Lower-than-actual'

# %%
def range_scale(x, min_target=100, max_target=300):
    return ((x - np.min(x)) / (np.max(x) - np.min(x)))*(max_target - min_target) + min_target

# %%
md.head()
# Out:
#            record_id  age_enroll  marital  gestage_by  insur  ethnicity  race  \
# unique_id
# 1024_10         1024        23.0      0.0         0.0    5.0        0.0   1.0
# 2180_12         2180        34.0      1.0         1.0    3.0        0.0   0.0
# 2148_11         2148        34.0      1.0         2.0    3.0        0.0   0.0
# 1062_8          1062        31.0      0.0         1.0    5.0        0.0   1.0
# 1306_7          1306        25.0      0.0         3.0    5.0        0.0   1.0
#
#             bmi_1vis  prior_ptb_all  fullterm_births  ...  visit_num  PQSI  \
# unique_id                                             ...
# 1024_10    21.378954            0.0              1.0  ...          1   4.0
# 2180_12    31.732640            0.0              0.0  ...          1  10.0
# 2148_11    22.406605            0.0              1.0  ...          1  11.0
# 1062_8     40.106270            0.0              0.0  ...          1   8.0
# 1306_7     24.555670            0.0              0.0  ...          1  10.0
#
#                 KPAS  EpworthSS  Edinburgh  Pre-term birth     y       yhat  \
# unique_id
# 1024_10     4.571429        0.0        0.0           False  10.0  15.463044
# 2180_12     9.053680        5.0        6.0           False  12.0  11.777130
# 2148_11    10.266234        9.0        7.0           False  11.0  18.814798
# 1062_8      9.493074        3.0        5.0           False   8.0  14.428290
# 1306_7      8.889610        9.0        9.0           False   7.0  16.641426
#
#            split     error
# unique_id
# 1024_10    train  5.463044
# 2180_12    train -0.222870
# 2148_11    train  7.814798
# 1062_8     train  6.428290
# 1306_7     train  9.641426
#
# [5 rows x 130 columns]

# %%
# regenerate 
# plot all significant and simulate them, show with barplots

# order by 
dt = pd.Series(md_node_annotation).reset_index().rename(columns={'index':'var', 0:'cat'})
dt['cat'].value_counts()
dt = dt.merge(pd.DataFrame(pd.DataFrame(moi).T.rename(columns={k:v for k,v in zip(list(range(3)), ['-log10P', 'AU-PRC', 'AU-PRC (%-diff)'])})), 
         left_on='var', right_index=True, how='left')
dtt = pd.DataFrame(columns=dt.columns)
for cat in dt.value_counts('cat').index:
    dtt = dtt.append(dt.loc[dt['cat']==cat, :].sort_values(by='-log10P', ascending=False), ignore_index=True)
dt = dtt 
del dtt

sig_voi_cat = {}
sig_voi_cont = {}
for i in dt.index:
    if dt.loc[i, '-log10P'] >= -1*np.log10(0.01):#p_threshold:
        if mdpred_voi[dt.loc[i, 'var']] == 'continuous':
            sig_voi_cont[dt.loc[i, 'var']] = mdpred_voi[dt.loc[i, 'var']]
        else:
            sig_voi_cat[dt.loc[i, 'var']] = mdpred_voi[dt.loc[i, 'var']]
del sig_voi_cat['ptb_37wks']

max_categorical_obsVexp_ratio = get_max_value(md, mdpred_voi) # from wearables.scripts.aesthetics import max_categorical_obsVexp_ratio


res_cat = md_grpdiff_perm_test(md.loc[md['split']=='train'], voi=sig_voi_cat, value=max_categorical_obsVexp_ratio, verbose=True)
# Out:
# /tmp/ipykernel_3986866/2724408599.py:59: RuntimeWarning: invalid value encountered in log2
#   'log2_grpVall' : {str(gg):np.log2(df.loc[df[groupby]==gg, g].mean()) - np.log2(df[g].mean()) for gg in df[groupby].unique()},
# through n=1 trials and i=1 var of 19 in 0-s
# through n=101 trials and i=1 var of 19 in 1-s
# through n=201 trials and i=1 var of 19 in 2-s
# through n=301 trials and i=1 var of 19 in 3-s
# through n=401 trials and i=1 var of 19 in 4-s
# through n=501 trials and i=1 var of 19 in 5-s
# through n=601 trials and i=1 var of 19 in 6-s
# through n=701 trials and i=1 var of 19 in 7-s
# through n=801 trials and i=1 var of 19 in 8-s
# through n=901 trials and i=1 var of 19 in 9-s
# through n=1 trials and i=2 var of 19 in 10-s
# through n=101 trials and i=2 var of 19 in 11-s
# through n=201 trials and i=2 var of 19 in 12-s
# through n=301 trials and i=2 var of 19 in 12-s
# through n=401 trials and i=2 var of 19 in 13-s
# through n=501 trials and i=2 var of 19 in 14-s
# through n=601 trials and i=2 var of 19 in 15-s
# through n=701 trials and i=2 var of 19 in 16-s
# through n=801 trials and i=2 var of 19 in 17-s
# through n=901 trials and i=2 var of 19 in 18-s
# through n=1 trials and i=3 var of 19 in 19-s
# through n=101 trials and i=3 var of 19 in 20-s
# through n=201 trials and i=3 var of 19 in 21-s
# through n=301 trials and i=3 var of 19 in 22-s
# through n=401 trials and i=3 var of 19 in 23-s
# through n=501 trials and i=3 var of 19 in 24-s
# through n=601 trials and i=3 var of 19 in 25-s
# through n=701 trials and i=3 var of 19 in 26-s
# through n=801 trials and i=3 var of 19 in 27-s
# through n=901 trials and i=3 var of 19 in 27-s
# through n=1 trials and i=4 var of 19 in 28-s
# through n=101 trials and i=4 var of 19 in 29-s
# through n=201 trials and i=4 var of 19 in 30-s
# through n=301 trials and i=4 var of 19 in 31-s
# through n=401 trials and i=4 var of 19 in 32-s
# through n=501 trials and i=4 var of 19 in 33-s
# through n=601 trials and i=4 var of 19 in 33-s
# through n=701 trials and i=4 var of 19 in 34-s
# through n=801 trials and i=4 var of 19 in 35-s
# through n=901 trials and i=4 var of 19 in 36-s
# through n=1 trials and i=5 var of 19 in 37-s
# through n=101 trials and i=5 var of 19 in 38-s
# through n=201 trials and i=5 var of 19 in 38-s
# through n=301 trials and i=5 var of 19 in 39-s
# through n=401 trials and i=5 var of 19 in 40-s
# through n=501 trials and i=5 var of 19 in 41-s
# through n=601 trials and i=5 var of 19 in 42-s
# through n=701 trials and i=5 var of 19 in 43-s
# through n=801 trials and i=5 var of 19 in 43-s
# through n=901 trials and i=5 var of 19 in 44-s
# through n=1 trials and i=6 var of 19 in 45-s
# through n=101 trials and i=6 var of 19 in 46-s
# through n=201 trials and i=6 var of 19 in 47-s
# through n=301 trials and i=6 var of 19 in 48-s
# through n=401 trials and i=6 var of 19 in 48-s
# through n=501 trials and i=6 var of 19 in 49-s
# through n=601 trials and i=6 var of 19 in 50-s
# through n=701 trials and i=6 var of 19 in 51-s
# through n=801 trials and i=6 var of 19 in 52-s
# through n=901 trials and i=6 var of 19 in 53-s
# through n=1 trials and i=7 var of 19 in 53-s
# through n=101 trials and i=7 var of 19 in 54-s
# through n=201 trials and i=7 var of 19 in 55-s
# through n=301 trials and i=7 var of 19 in 56-s
# through n=401 trials and i=7 var of 19 in 57-s
# through n=501 trials and i=7 var of 19 in 58-s
# through n=601 trials and i=7 var of 19 in 59-s
# through n=701 trials and i=7 var of 19 in 60-s
# through n=801 trials and i=7 var of 19 in 61-s
# through n=901 trials and i=7 var of 19 in 62-s
# through n=1 trials and i=8 var of 19 in 63-s
# through n=101 trials and i=8 var of 19 in 64-s
# through n=201 trials and i=8 var of 19 in 65-s
# through n=301 trials and i=8 var of 19 in 66-s
# through n=401 trials and i=8 var of 19 in 67-s
# through n=501 trials and i=8 var of 19 in 67-s
# through n=601 trials and i=8 var of 19 in 68-s
# through n=701 trials and i=8 var of 19 in 69-s
# through n=801 trials and i=8 var of 19 in 70-s
# through n=901 trials and i=8 var of 19 in 71-s
# through n=1 trials and i=9 var of 19 in 71-s
# through n=101 trials and i=9 var of 19 in 73-s
# through n=201 trials and i=9 var of 19 in 74-s
# through n=301 trials and i=9 var of 19 in 75-s
# through n=401 trials and i=9 var of 19 in 76-s
# through n=501 trials and i=9 var of 19 in 77-s
# through n=601 trials and i=9 var of 19 in 78-s
# through n=701 trials and i=9 var of 19 in 79-s
# through n=801 trials and i=9 var of 19 in 80-s
# through n=901 trials and i=9 var of 19 in 81-s
# through n=1 trials and i=10 var of 19 in 82-s
# through n=101 trials and i=10 var of 19 in 83-s
# through n=201 trials and i=10 var of 19 in 84-s
# through n=301 trials and i=10 var of 19 in 85-s
# through n=401 trials and i=10 var of 19 in 86-s
# through n=501 trials and i=10 var of 19 in 87-s
# through n=601 trials and i=10 var of 19 in 88-s
# through n=701 trials and i=10 var of 19 in 89-s
# through n=801 trials and i=10 var of 19 in 90-s
# through n=901 trials and i=10 var of 19 in 91-s
# through n=1 trials and i=11 var of 19 in 92-s
# through n=101 trials and i=11 var of 19 in 93-s
# through n=201 trials and i=11 var of 19 in 94-s
# through n=301 trials and i=11 var of 19 in 95-s
# through n=401 trials and i=11 var of 19 in 96-s
# through n=501 trials and i=11 var of 19 in 97-s
# through n=601 trials and i=11 var of 19 in 98-s
# through n=701 trials and i=11 var of 19 in 99-s
# through n=801 trials and i=11 var of 19 in 100-s
# through n=901 trials and i=11 var of 19 in 101-s
# through n=1 trials and i=12 var of 19 in 102-s
# through n=101 trials and i=12 var of 19 in 103-s
# through n=201 trials and i=12 var of 19 in 104-s
# through n=301 trials and i=12 var of 19 in 105-s
# through n=401 trials and i=12 var of 19 in 107-s
# through n=501 trials and i=12 var of 19 in 108-s
# through n=601 trials and i=12 var of 19 in 109-s
# through n=701 trials and i=12 var of 19 in 110-s
# through n=801 trials and i=12 var of 19 in 111-s
# through n=901 trials and i=12 var of 19 in 112-s
# through n=1 trials and i=13 var of 19 in 113-s
# through n=101 trials and i=13 var of 19 in 114-s
# through n=201 trials and i=13 var of 19 in 115-s
# through n=301 trials and i=13 var of 19 in 116-s
# through n=401 trials and i=13 var of 19 in 117-s
# through n=501 trials and i=13 var of 19 in 118-s
# through n=601 trials and i=13 var of 19 in 119-s
# through n=701 trials and i=13 var of 19 in 120-s
# through n=801 trials and i=13 var of 19 in 121-s
# through n=901 trials and i=13 var of 19 in 122-s
# through n=1 trials and i=14 var of 19 in 123-s
# through n=101 trials and i=14 var of 19 in 124-s
# through n=201 trials and i=14 var of 19 in 125-s
# through n=301 trials and i=14 var of 19 in 126-s
# through n=401 trials and i=14 var of 19 in 127-s
# through n=501 trials and i=14 var of 19 in 128-s
# through n=601 trials and i=14 var of 19 in 129-s
# through n=701 trials and i=14 var of 19 in 130-s
# through n=801 trials and i=14 var of 19 in 131-s
# through n=901 trials and i=14 var of 19 in 132-s
# through n=1 trials and i=15 var of 19 in 133-s
# through n=101 trials and i=15 var of 19 in 134-s
# through n=201 trials and i=15 var of 19 in 135-s
# through n=301 trials and i=15 var of 19 in 136-s
# through n=401 trials and i=15 var of 19 in 137-s
# through n=501 trials and i=15 var of 19 in 138-s
# through n=601 trials and i=15 var of 19 in 139-s
# through n=701 trials and i=15 var of 19 in 140-s
# through n=801 trials and i=15 var of 19 in 141-s
# through n=901 trials and i=15 var of 19 in 142-s
# through n=1 trials and i=16 var of 19 in 143-s
# through n=101 trials and i=16 var of 19 in 144-s
# through n=201 trials and i=16 var of 19 in 145-s
# through n=301 trials and i=16 var of 19 in 146-s
# through n=401 trials and i=16 var of 19 in 147-s
# through n=501 trials and i=16 var of 19 in 148-s
# through n=601 trials and i=16 var of 19 in 149-s
# through n=701 trials and i=16 var of 19 in 150-s
# through n=801 trials and i=16 var of 19 in 151-s
# through n=901 trials and i=16 var of 19 in 152-s
# through n=1 trials and i=17 var of 19 in 153-s
# through n=101 trials and i=17 var of 19 in 154-s
# through n=201 trials and i=17 var of 19 in 155-s
# through n=301 trials and i=17 var of 19 in 156-s
# through n=401 trials and i=17 var of 19 in 157-s
# through n=501 trials and i=17 var of 19 in 158-s
# through n=601 trials and i=17 var of 19 in 159-s
# through n=701 trials and i=17 var of 19 in 160-s
# through n=801 trials and i=17 var of 19 in 161-s
# through n=901 trials and i=17 var of 19 in 161-s
# through n=1 trials and i=18 var of 19 in 162-s
# through n=101 trials and i=18 var of 19 in 163-s
# through n=201 trials and i=18 var of 19 in 164-s
# through n=301 trials and i=18 var of 19 in 165-s
# through n=401 trials and i=18 var of 19 in 166-s
# through n=501 trials and i=18 var of 19 in 167-s
# through n=601 trials and i=18 var of 19 in 167-s
# through n=701 trials and i=18 var of 19 in 168-s
# through n=801 trials and i=18 var of 19 in 169-s
# through n=901 trials and i=18 var of 19 in 170-s
# through n=1 trials and i=19 var of 19 in 171-s
# through n=101 trials and i=19 var of 19 in 172-s
# through n=201 trials and i=19 var of 19 in 173-s
# through n=301 trials and i=19 var of 19 in 174-s
# through n=401 trials and i=19 var of 19 in 175-s
# through n=501 trials and i=19 var of 19 in 175-s
# through n=601 trials and i=19 var of 19 in 176-s
# through n=701 trials and i=19 var of 19 in 177-s
# through n=801 trials and i=19 var of 19 in 178-s
# through n=901 trials and i=19 var of 19 in 179-s
#
# Results:
#   hypertension:
#     Higher-than-actual	1.66
#     Lower-than-actual	0.00
#     lt10wks	1.12
#   pregestational_diabetes:
#     Higher-than-actual	1.55
#     Lower-than-actual	0.00
#     lt10wks	1.14
#   other_disease:
#     Higher-than-actual	1.66
#     Lower-than-actual	0.00
#     lt10wks	1.13
#   prior_ptb_all:
#     Higher-than-actual	1.39
#     Lower-than-actual	0.80
#     lt10wks	0.99
#   ppvisit_dx:
#     Higher-than-actual	1.23
#     Lower-than-actual	0.89
#     lt10wks	1.00
#   corticosteroids:
#     Higher-than-actual	0.97
#     Lower-than-actual	0.53
#     lt10wks	1.10
#   deliv_mode:
#     Higher-than-actual	2.02
#     Lower-than-actual	0.00
#     lt10wks	1.09
#   epidural:
#     Higher-than-actual	1.24
#     Lower-than-actual	0.78
#     lt10wks	1.01
#   gestage_by:
#     Higher-than-actual	1.35
#     Lower-than-actual	0.42
#     lt10wks	1.02
#   afterlunch1:
#     Higher-than-actual	1.71
#     Lower-than-actual	0.32
#     lt10wks	1.05
#   talking1:
#     Higher-than-actual	0.50
#     Lower-than-actual	1.62
#     lt10wks	0.82
#   reset1:
#     Higher-than-actual	2.29
#     Lower-than-actual	0.91
#     lt10wks	0.85
#   cartraffic1:
#     Higher-than-actual	1.62
#     Lower-than-actual	0.34
#     lt10wks	1.06
#   slp30_1trim:
#     Higher-than-actual	1.60
#     Lower-than-actual	0.30
#     lt10wks	1.07
#   slpwake_1trim:
#     Higher-than-actual	1.65
#     Lower-than-actual	0.30
#     lt10wks	1.07
#   tv1:
#     Higher-than-actual	1.64
#     Lower-than-actual	0.35
#     lt10wks	1.06
#   alcohol:
#     Higher-than-actual	1.50
#     Lower-than-actual	0.15
#     lt10wks	1.11
#   income_annual1:
#     Higher-than-actual	1.15
#     Lower-than-actual	1.20
#     lt10wks	0.94
#   smoke:
#     Higher-than-actual	1.34
#     Lower-than-actual	0.00
#     lt10wks	1.17
#   hypertension_null:
#     Higher-than-actual	0.98
#     Lower-than-actual	0.98
#     lt10wks	1.00
#   pregestational_diabetes_null:
#     Higher-than-actual	0.98
#     Lower-than-actual	0.95
#     lt10wks	1.01
#   other_disease_null:
#     Higher-than-actual	1.03
#     Lower-than-actual	1.01
#     lt10wks	1.00
#   prior_ptb_all_null:
#     Higher-than-actual	0.97
#     Lower-than-actual	1.02
#     lt10wks	1.00
#   ppvisit_dx_null:
#     Higher-than-actual	1.00
#     Lower-than-actual	0.98
#     lt10wks	1.00
#   corticosteroids_null:
#     Higher-than-actual	0.97
#     Lower-than-actual	0.97
#     lt10wks	1.01
#   deliv_mode_null:
#     Higher-than-actual	0.92
#     Lower-than-actual	1.00
#     lt10wks	1.01
#   epidural_null:
#     Higher-than-actual	0.99
#     Lower-than-actual	1.00
#     lt10wks	1.00
#   gestage_by_null:
#     Higher-than-actual	1.02
#     Lower-than-actual	0.93
#     lt10wks	0.95
#   afterlunch1_null:
#     Higher-than-actual	1.01
#     Lower-than-actual	0.97
#     lt10wks	1.00
#   talking1_null:
#     Higher-than-actual	0.95
#     Lower-than-actual	0.94
#     lt10wks	0.91
#   reset1_null:
#     Higher-than-actual	0.98
#     Lower-than-actual	0.96
#     lt10wks	1.01
#   cartraffic1_null:
#     Higher-than-actual	1.02
#     Lower-than-actual	1.00
#     lt10wks	0.99
#   slp30_1trim_null:
#     Higher-than-actual	1.00
#     Lower-than-actual	0.98
#     lt10wks	1.00
#   slpwake_1trim_null:
#     Higher-than-actual	1.01
#     Lower-than-actual	1.00
#     lt10wks	1.00
#   tv1_null:
#     Higher-than-actual	1.01
#     Lower-than-actual	1.00
#     lt10wks	1.00
#   alcohol_null:
#     Higher-than-actual	0.99
#     Lower-than-actual	0.99
#     lt10wks	1.00
#   income_annual1_null:
#     Higher-than-actual	1.01
#     Lower-than-actual	0.99
#     lt10wks	1.00
#   smoke_null:
#     Higher-than-actual	1.00
#     Lower-than-actual	1.07
#     lt10wks	0.99

# %%
max_categorical_obsVexp_ratio
# Out:
# {'marital': 1.0,
#  'gestage_by': 0.0,
#  'insur': 0.0,
#  'ethnicity': 1.0,
#  'race': 0.0,
#  'prior_ptb_all': 1.0,
#  'fullterm_births': 0.0,
#  'surghx_none': 0.0,
#  'alcohol': 2.0,
#  'smoke': 2.0,
#  'drugs': 2.0,
#  'hypertension': 2.0,
#  'pregestational_diabetes': 2.0,
#  'asthma_yes___1': 1.0,
#  'asthma_yes___2': 1.0,
#  'asthma_yes___3': 1.0,
#  'asthma_yes___4': 1.0,
#  'asthma_yes___5': 1.0,
#  'asthma_yes___7': 1.0,
#  'asthma_yes___8': 1.0,
#  'asthma_yes___10': 1.0,
#  'asthma_yes___13': 1.0,
#  'asthma_yes___18': 1.0,
#  'asthma_yes___19': 1.0,
#  'asthma_yes___20': 1.0,
#  'other_disease': 2.0,
#  'gestational_diabetes': 1.0,
#  'ghtn': 1.0,
#  'preeclampsia': 1.0,
#  'rh': 1.0,
#  'corticosteroids': 1.0,
#  'abuse': 1.0,
#  'assist_repro': 1.0,
#  'gyn_infection': 1.0,
#  'ptb_37wks': 1.0,
#  'anes_type': 6.0,
#  'epidural': 0.0,
#  'deliv_mode': 3.0,
#  'death_baby': 1.0,
#  'neonatal_complication': 1.0,
#  'ervisit': 1.0,
#  'ppvisit_dx': 1.0,
#  'education': 0.0,
#  'paidjob1': 0.0,
#  'work_hrs1': 1.0,
#  'income_annual1': 1.0,
#  'income_support1': 0.0,
#  'regular_period1': 0.0,
#  'period_window1': 1.0,
#  'menstrual_days1': 0.0,
#  'bc_past1': 0.0,
#  'months_noprego1': 1.0,
#  'premature_birth1': 0.0,
#  'stress1_1': 0.0,
#  'stress2_1': 0.0,
#  'stress3_1': 0.0,
#  'stress4_1': 0.0,
#  'stress5_1': 0.0,
#  'stress6_1': 0.0,
#  'stress7_1': 0.0,
#  'stress8_1': 0.0,
#  'stress9_1': 0.0,
#  'stress10_1': 0.0,
#  'workreg_1trim': 0.0,
#  'choosesleep_1trim': 0.0,
#  'slpwake_1trim': 0.0,
#  'slp30_1trim': 0.0,
#  'sleep_qual1': 0.0,
#  'slpenergy1': 0.0,
#  'sitting1': 0.0,
#  'tv1': 0.0,
#  'inactive1': 0.0,
#  'passenger1': 0.0,
#  'reset1': 5.0,
#  'talking1': 4.0,
#  'afterlunch1': 0.0,
#  'cartraffic1': 0.0,
#  'edinb1_1trim': 4.0,
#  'edinb2_1trim': 4.0,
#  'edinb3_1trim': 0.0,
#  'edinb4_1trim': 0.0,
#  'edinb5_1trim': 4.0,
#  'edinb6_1trim': 4.0,
#  'edinb7_1trim': 0.0,
#  'edinb8_1trim': 4.0,
#  'edinb9_1trim': 4.0,
#  'edinb10_1trim': 4.0}

# %%
from scipy.stats import kruskal, ttest_ind, mannwhitneyu

# %%
def p_encoder(p):
    if p > 0.05:
        label = '' # n.s.
    elif p <= 0.001:
        label = '***'
    elif p <= 0.05 and p > 0.01:
        label = '*'
    elif p <= 0.01 and p > 0.001:
        label = '**'
    else: 
        label = 'Unclassified'
    return label

# %%
## kruskala wallis per var and later bonferonni
print('Across group comparison and btw higher and normal and lower and normal pvals:')
n = len(sig_voi_cat.keys())
print('  n={} comparisons'.format(n))  
for k in sig_voi_cat.keys():
    stat, p = kruskal(*[res_cat[k][kk] for kk in res_cat[k].keys()])
    stat_n, p_n = mannwhitneyu(res_cat[k]['lt10wks'], res_cat[f"{k}_null"]['lt10wks'])
    stat_hvn, p_hvn = mannwhitneyu(res_cat[k]['Higher-than-actual'], res_cat[f"{k}_null"]['Higher-than-actual'])
    stat_lvn, p_lvn = mannwhitneyu(res_cat[k]['Lower-than-actual'], res_cat[f"{k}_null"]['Lower-than-actual'])
    
    p = p*n
    p_n = p_n*n
    p_hvn = p_hvn*n
    p_lvn = p_lvn*n
    
    print(f"{k}\tGroup P: {p:.2e}{p_encoder(p)}\tp_norm: {p_n:.2e}{p_encoder(p_n)}\tp_high: {p_hvn:.2e}{p_encoder(p_hvn)}\tp_low: {p_lvn:.2e}{p_encoder(p_lvn)}")
# Out:
# Across group comparison and btw higher and normal and lower and normal pvals:
#   n=19 comparisons
# hypertension	Group P: 0.00e+00***	p_norm: 3.98e-34***	p_high: 2.15e-21***	p_low: 2.27e-193***
# pregestational_diabetes	Group P: 1.83e-307***	p_norm: 4.75e-36***	p_high: 2.52e-14***	p_low: 9.77e-192***
# other_disease	Group P: 0.00e+00***	p_norm: 3.66e-50***	p_high: 1.83e-27***	p_low: 1.20e-249***
# prior_ptb_all	Group P: 7.53e-121***	p_norm: 3.10e+00	p_high: 2.09e-40***	p_low: 1.76e-27***
# ppvisit_dx	Group P: 2.36e-204***	p_norm: 5.12e-03**	p_high: 7.08e-61***	p_low: 5.06e-23***
# corticosteroids	Group P: 4.35e-208***	p_norm: 1.64e-70***	p_high: 8.34e+00	p_low: 3.96e-107***
# deliv_mode	Group P: 0.00e+00***	p_norm: 2.00e-21***	p_high: 3.07e-92***	p_low: 2.25e-294***
# epidural	Group P: 7.90e-205***	p_norm: 9.87e-06***	p_high: 6.12e-40***	p_low: 1.08e-63***
# gestage_by	Group P: 3.75e-115***	p_norm: 8.54e-05***	p_high: 3.46e-03**	p_low: 2.39e-24***
# afterlunch1	Group P: 0.00e+00***	p_norm: 3.78e-16***	p_high: 2.82e-67***	p_low: 1.17e-162***
# talking1	Group P: 6.40e-126***	p_norm: 2.63e-05***	p_high: 5.69e-08***	p_low: 4.01e-18***
# reset1	Group P: 9.80e-56***	p_norm: 2.48e-26***	p_high: 1.36e-50***	p_low: 5.02e+00
# cartraffic1	Group P: 0.00e+00***	p_norm: 2.27e-22***	p_high: 1.30e-55***	p_low: 9.50e-158***
# slp30_1trim	Group P: 0.00e+00***	p_norm: 3.30e-25***	p_high: 2.41e-49***	p_low: 7.29e-159***
# slpwake_1trim	Group P: 0.00e+00***	p_norm: 3.38e-30***	p_high: 2.82e-55***	p_low: 5.52e-175***
# tv1	Group P: 0.00e+00***	p_norm: 1.11e-22***	p_high: 1.08e-51***	p_low: 4.99e-148***
# alcohol	Group P: 0.00e+00***	p_norm: 5.60e-45***	p_high: 1.02e-22***	p_low: 1.73e-175***
# income_annual1	Group P: 1.86e-77***	p_norm: 4.91e-46***	p_high: 6.77e-09***	p_low: 7.41e-35***
# smoke	Group P: 0.00e+00***	p_norm: 6.37e-106***	p_high: 5.43e-10***	p_low: 6.39e-275***

# %% [markdown]
# ### re-make plot and print out values for writing

# %%
# regen plot
resknn10 = loadpkl(os.path.join(pfp, 'md_predictability_knn_10wk.pkl'))
moi = wearutils.metric_list(resknn10, mdpred_voi, top1=True) #, clf_metric='balanced_acc')

dt = pd.Series(md_node_annotation).reset_index().rename(columns={'index':'var', 0:'cat'})
dt['cat'].value_counts()
dt = dt.merge(pd.DataFrame(pd.DataFrame(moi).T.rename(columns={k:v for k,v in zip(list(range(3)), ['-log10P', 'AU-PRC', 'AU-PRC (%-diff)'])})), 
         left_on='var', right_index=True, how='left')
# actually, not the right name in the columns
dt = dt.rename(columns={'AU-PRC': 'AU-PRC or Rho', 'AU-PRC (%-diff)': '%-diff or MAPE'})

# re-rank
dtt = pd.DataFrame(columns=dt.columns)
for cat in dt.value_counts('cat').index:
    dtt = dtt.append(dt.loc[dt['cat']==cat, :].sort_values(by='AU-PRC or Rho', ascending=False), ignore_index=True)
dt = dtt 
del dtt
dtt = dt.loc[dt['cat']==cat, :]
x, y, c = dtt['var'], dtt['AU-PRC or Rho'], dtt['%-diff or MAPE']

# seperate per grp 
fig = plt.figure(figsize=(10, 12))
for i, cat in enumerate(dt['cat'].unique()):
    ax = fig.add_subplot(4, 2, i+1)
    dtt = dt.loc[dt['cat']==cat, :]
    x, y, c = dtt['var'], dtt['AU-PRC or Rho'], dtt['%-diff or MAPE']
    im = ax.scatter(x, y, c=c, s=range_scale(c, min_target=10, max_target=100), vmin=0, vmax=1, cmap='RdYlBu_r')
    for ii in range(len(x)):
        ax.plot([x.iloc[ii], x.iloc[ii]], [0, y.iloc[ii]], 'k--', linewidth=0.5, zorder=0)
    ax.set_xticklabels(x, rotation=90)
#     fig.colorbar(im, ax=ax, label='%-diff or MAPE')
    ax.set_ylabel("AU-PRC or Spearman's Rho")
    ax.set_ylim([0, 1.1])
    ax.set_yticks([0, 0.2, 0.4, 0.6, 0.8, 1])
    ax.set_title(cat)
fig.tight_layout()
if savefigs:
    fig.savefig(os.path.join(pfp, 'barplot_AUPRC-RhoVvars_by_cat_2.pdf'), bbox_inches='tight')
# Out:
# /tmp/ipykernel_3986866/1178560860.py:27: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x, rotation=90)
# /tmp/ipykernel_3986866/1178560860.py:27: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x, rotation=90)
# /tmp/ipykernel_3986866/1178560860.py:27: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x, rotation=90)
# /tmp/ipykernel_3986866/1178560860.py:27: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x, rotation=90)
# /tmp/ipykernel_3986866/1178560860.py:27: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x, rotation=90)
# /tmp/ipykernel_3986866/1178560860.py:27: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x, rotation=90)
# /tmp/ipykernel_3986866/1178560860.py:27: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x, rotation=90)
# /tmp/ipykernel_3986866/1178560860.py:27: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x, rotation=90)
